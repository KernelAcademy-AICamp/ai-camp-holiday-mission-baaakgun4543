# %%
import os
import urllib

import certifi
from pymongo.server_api import ServerApi
from pymongo import MongoClient
from dotenv import load_dotenv
load_dotenv()

username = urllib.parse.quote_plus(os.environ['MONGODB_USERNAME'])
password = urllib.parse.quote_plus(os.environ['MONGODB_PASSWORD'])
uri = f"mongodb+srv://{username}:{password}@cluster0.dul5xz0.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri, server_api=ServerApi('1'), tlsCAFile=certifi.where())
db = client.restaurant_db
collection = db.restaurant_info

# restaurants_info = list(collection.find({}, {'_id': False}))
restaurants_info = list(collection.find({}))
restaurants_info
# Out:
# [{'_id': '1363980',
#   'restaurant': 'BHC-금호동점',
#   'reviews': [{'menus': '뿌링클 콤보/1(음료선택 (서비스음료 미제공))',
#     'review_text': '맛잇어요!!!!!!'},
#    {'menus': '레드킹순살/1(음료선택 (서비스음료 미제공))', 'review_text': '매번 맛있게 잘 먹고 있어요.^^'},
#    {'menus': '맛초킹순살/1(음료선택 (서비스음료 미제공))',
#     'review_text': '요즘 치킨 체인들이 이런저런 이유로 가격을 올리고 서비스도 점점 줄어 드네요 교촌도 그래서 소비자들이 외면하는데 BHC는 안그랬으면 하네요 매장에서 먹을때보다 못한거 같네요 맛은 좋지만요'},
#    {'menus': '쏘마치/1(음료선택 (콜라 1.25L))',
#     'review_text': '넘 맛있어요~~ 적당히 맵고 달달하니 ㅎㅎ'},
#    {'menus': '맛초킹/1(음료선택 (서비스음료 미제공))', 'review_text': '너무 짜요. ㅠㅠㅠㅠ'},
#    {'menus': '맛초킹순살/1(음료선택 (콜라 1.25L),요청사항(미체크 시 기본제공) (치킨무 X),요청사항(미체크 시 기본제공) (기본제공 소스 X),디저트 (빨간소떡))',
#     'review_text': '치맥 땡길 때 시켜 먹슴다..'},
#    {'menus': '콰삭킹/1(음료선택 (서비스음료 미제공),요청사항(미체크 시 기본제공) (치킨무 X)),스윗하바네로소스(40g)/2',
#     'review_text': '넘넘넘넘맛있어용!!'},
#    {'menus': '콰삭킹 콤보/1(음료선택 (서비스음료 미제공)),뿌링클 콤보/1(음료선택 (서비스음료 미제공))',
#     'review_text': '콰삭킹은 진짜 콰사삭합니다 짱맛~'},
#    {'menus': '맛초킹/1(음료선택 (콜라 245ml)),소주/1', 'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': 'HOT후라이드/1(음료선택 (서비스음료 미제공),요청사항(미체크 시 기본제공) (치킨무 X),소스 (스윗하바네로소스(40g) 추가),옵션 (양념소스))',
#     'review_text': '넘넘맛있어요^^행복해욤'},
#    {'menus': '레드킹순살/1(음료선택 (서비스음료 미제공)),케이준프라이/1',
#     'review_text': '이번에도 잘 먹었습니다~~!!'},
#    {'menus': '골드킹/1(음료선택 (콜라 245ml))',
#     'review_text': '골드킹 좋아해서 자주 시켜 먹어요 맛있어요'},
#    {'menus': '골드킹/1(음료선택 (서비스음료 미제공)),코카콜라 제로 1.25L./1',
#     'review_text': '맛있어요 치킨은 여기서 시켜요'},
#    {'menus': '맛초킹순살/1(음료선택 (서비스음료 미제공))',
#     'review_text': '오랜만에 먹었는데, 맛있게 잘 먹었습니다~'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공)),뿌링치즈볼/1',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '처음 주문했는데 소스가 많아서 좋았어요\n감사합니다'},
#    {'menus': '골드킹/1(음료선택(서비스음료 미제공)),코카콜라 제로 355ml/1',
#     'review_text': '맛있게 먹을게요 치킨은 항상 여기서 시켜요'},
#    {'menus': '후라이드 콤보＋치즈볼/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X),옵션(치킨무))',
#     'review_text': '닭을 너무 튀겨서 과자같아요.\n취향이겠지만 맛이없진않았어요.\n치즈볼은 진짜 맛있네요.'},
#    {'menus': '골드킹/1(음료선택(서비스음료 미제공)),콰삭킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '맛있고 만족합니다~^^'},
#    {'menus': '골드킹 순살/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘먹겠습니다!'},
#    {'menus': '케이준프라이/1,레드킹순살/1(음료선택(서비스음료 미제공))',
#     'review_text': '오랜만에 잘 먹었습니다~'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '이사와서 처음 먹었는데\n소스도 엄청 풍부하고\n이제까지 먹은 bhc중에 제일 맛있었어요!'},
#    {'menus': '뿌링클 스틱/1(음료선택(콜라 1.25L)),뿌링치즈볼/2',
#     'review_text': '진짜 굿굿 다이어트중인데 못참았어요 맛도리!!'},
#    {'menus': '뿌링클/1(음료선택(서비스음료 미제공))',
#     'review_text': '더운 날 수고 많으십니다. 감사히 잘 먹었습니다.'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공))',
#     'review_text': '빠르게 배달해 주셔서 맛있게 잘 먹었습니다. 감사합니다.\n.'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공)),코카콜라 제로 1.25L./1',
#     'review_text': '맛초킹 오랜만에 먹는데 맛있어요'},
#    {'menus': '콰삭킹 콤보/1(음료선택(콜라 1.25L),소스(뿌링뿌링소스 추가),옵션(치킨무)),(NEW) 맛초킹라이스/1,치로스/1(디저트(뿌링치즈스틱))',
#     'review_text': '전화까지드려서 말씀드렸는데도 전에 처럼 닭이 과자 처럼 너무 바삭해요.\n컽 바삭 속 촉촉 까지는 아니어도 이정도 아니었으면 좋겠어요.ㅠㅠ'},
#    {'menus': '콰삭킹 순살/1(음료선택(서비스음료 미제공))', 'review_text': '너무 맛이 좋아요!!'},
#    {'menus': '후라이드 스틱/1(음료선택(서비스음료 미제공))', 'review_text': '잘받았습니다 잘받았습니다'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '맛있었습니다. 역시 믿고 먹는 bhc금호점 맛초킹'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공)),골드킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '빠른 배달해 주셔서 늦지 않게 잘 먹었습니다. 생각보다 기름진 느낌은 있었지만 맛있게 잘 먹었습니다. 감사합니다 .'},
#    {'menus': '(반반치킨)후라이드/양념/1(음료선택(서비스음료 미제공))',
#     'review_text': '서비스 요청없었는데 서비스도 주시고 하나만 먹었는데 너무 맛있어서 정신없이 찍었습니다. 넘 맛있습니다'},
#    {'menus': '뿌링클＋치즈볼/1(음료선택(서비스음료 미제공))',
#     'review_text': '치킨 맛있게 먹었습니다^^ 항상 맛있는 치킨 감사합니다!!!'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공))', 'review_text': '신메뉴도 맛있네요. 만족합니다'},
#    {'menus': '후라이드 윙/1(음료선택(콜라 245ml))', 'review_text': '잘받았습니다  맛있습니다'},
#    {'menus': '골드킹 윙/1(음료선택(서비스음료 미제공))', 'review_text': '맛있는데 조금 짭잘했어요'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '처음 먹어보고 맛있어서 최애 메뉴 됐습니다.'},
#    {'menus': '레드킹순살/1(음료선택(콜라 500ml),디저트(케이준프라이))',
#     'review_text': '맛있게 매운 거 먹고 스크레스 잘 풀었습니다!!'},
#    {'menus': '골드킹 콤보/1(음료선택(콜라 245ml),디저트(단팥꽈배기))',
#     'review_text': '항상 맛있게 잘 먹었습니다.'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '금호점 맛초킹은 실패가 없는 메뉴인데...\n오늘은 실패네요.\n소위 퍽퍽살이 촉촉한 게 금호점의 확고한 비교우위인데... 오늘은 퍽퍽했습니다. 얇은 부분은 정도가 심해서... 촉촉함은 전혀 없고 오히려 건어물 씹는 듯항 뻑뻑 질깃한 식감이었네요.\n항상 좋은 퀄리티 음식 제공하는 곳인지라 어쩌다 한번 그런 것일 것으로 생각하지만... 어쨌든 이번엔 실망이었습니다. 다음번엔 이런 일 없었으면 좋겠네요.'},
#    {'menus': '골드킹 윙/1(음료선택(서비스음료 미제공),옵션(양념소스))',
#     'review_text': '정신없이 먹었네요 맛있어요~~^^'},
#    {'menus': '맛초킹 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '양도 많고 매콤하면서 달달하니 맛있어요'},
#    {'menus': 'HOT후라이드 콤보/1(음료선택(서비스음료 미제공))', 'review_text': '수요일에 핫핫후라이드~'},
#    {'menus': '후라이드/1(음료선택(콜라 245ml))', 'review_text': '맛있습니다 조아요 굿'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))', 'review_text': '늘 맛있는 안정된 맛'},
#    {'menus': '(반반치킨)후라이드/양념/1(음료선택(서비스음료 미제공))',
#     'review_text': '이번에 닭이 너무 부드럽고 맛있었어요 금호점 최고입니다♡♡♡'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '양이 어마어마 잘 먹었어요'},
#    {'menus': '콰삭킹/1(음료선택(콜라 245ml))', 'review_text': '잘받았습니다  맛있어요'},
#    {'menus': '콰삭킹 콤보/1(음료선택(서비스음료 미제공))', 'review_text': '다 아는맛입니나.맛이어요'},
#    {'menus': '레드킹순살/1(음료선택(서비스음료 미제공))',
#     'review_text': '스트레스 풀땐 매콤한 레드킹으로…ㅎㅎㅎ'},
#    {'menus': '후라이드 윙/1(음료선택(콜라 1.25L))',
#     'review_text': '바삭바삭 맛있어요~\n양도 푸짐 합니다'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X),옵션(양념소스)),양념소스/1',
#     'review_text': '맛잇어용!! 핫후만 먹다가 이거먹어봑는데 당분간 요걸로만 시킬듯해용'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))', 'review_text': '와 진짜 너무 맛있어요ㅎㅎ 감사합니다'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '중학교때부터 치킨은 10년동안 맛초킹만 먹고 있어요. 학창시절에도 먹었고, 대학교 다니고 있는 지금도 먹고있는만큼 제게는 특별한 음식이기에 정말 잘 알고있는 음식인데요, 금호동점이 최고인 것 같습니다. 여러모로 타 지점에 비해 신경써주시는 점이 많다는 생각이 드네요. 항상 맛있게 해서 보내주셔서 감사합니다.'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '바삭바삭 감칠맛 너무 맛있어요'},
#    {'menus': '콰삭킹+분모자 로제 떡볶이/1(음료선택(콜라 245ml))',
#     'review_text': '매장에서도 먹지만 오늘은 집에서 고고~ \n먹고 싶은 메뉴가 많지만 오늘은 바삭한 콰사킹으로 주문\n맛있게 잘먹었는데 로제 떡볶이는 국물이 흘러 엉망이네요 좀 실망이에요 배달도 매장에서도 좀 신경을 써주셨으면 하네요'},
#    {'menus': 'HOT후라이드 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '오늘 유독 쫌더 핫하네 ㅋ 맛있음.'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X),옵션(양념소스))',
#     'review_text': '늘맛잇어요 바삭바삭!!'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공))', 'review_text': '바삭하고 맛나요 또 시킬듯'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공)),달콤바삭치즈볼/1,(NEW) 뿌링클나쵸/1',
#     'review_text': '맛있게 잘 먹었습니다~'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(기본제공 소스 X))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공))',
#     'review_text': '배달도 빠르고 따끈하니 맛있습니다.'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공))',
#     'review_text': '막 튀기자마자 뜨거운 상태 그대로 배달되서 너무 좋았습니다! 맛있어요 ㅠㅠ'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공),디저트(빨간소떡))',
#     'review_text': '따뜻한 뿌힝클 너무 맛있어..\n잘먹었습니다'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '배송 빠르고 좋습니다!'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공))', 'review_text': '좋아요 잘 먹엇어요'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공))', 'review_text': '오랜만에 맛있게 잘 먹었습니다!'},
#    {'menus': '후라이드（반）＋뿌링치즈볼＋콜라245ml/1', 'review_text': '잘받았습니다 잘받았습니다'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X),소스(스윗하바네로소스(40g) 추가),디저트(분모자 로제 떡볶이),옵션(양념소스))',
#     'review_text': '너어어어어어무 맛있었어요'},
#    {'menus': '(반반치킨)후라이드/양념/1(음료선택(서비스음료 미제공))',
#     'review_text': '바삭한 후라이드, 양념은 고추장맛도 살짝 나고 꾸덕한 양념치킨'},
#    {'menus': '콰삭킹/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '바삭바삭 맛있어요'},
#    {'menus': '레드킹순살/1(음료선택(서비스음료 미제공))', 'review_text': '매콤해서 스트레스 확 풀리네요.^^'},
#    {'menus': '뿌링클 스틱/1(음료선택(콜라 1.25L),디저트(뿌링치즈볼))',
#     'review_text': '맛있어여 👍👍👍🫶🏻🫶🏻❤️❤️'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공)),뿌링감자/1,코카콜라 1.25L./1',
#     'review_text': '배송이 엉망이였음 해당 배송기사는 안쓰시는게 좋을것같아요  집앞이 아닌 외부인이 다니는 외부에 두고 가는건 처음 경험해봄 덕분에 다 식은것 먹음'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '아이들이 제일 좋아하는 뿌링클 콤보^^\n순식간에 먹어치워서 사진을 못 찍었어요~~\n배달도 빨리와서 따뜻하게 잘먹었습니다'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '바삭하고 맛있습니다 ㅎㅎ'},
#    {'menus': '뿌링클순살/1(음료선택(콜라 1.25L),디저트(치로스))',
#     'review_text': '빠른 배송과 맛 최고 입니다.'},
#    {'menus': '골드킹/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(소스 X))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))', 'review_text': '배신하지 않는 맛. 만족스럽습니다'},
#    {'menus': '뿌링클 스틱/1(음료선택(콜라 1.25L),디저트(뿌링치즈볼))',
#     'review_text': '👍👍👍👍👍귯굿굿ㄱ ㅅ굿'},
#    {'menus': '골드킹/1(음료선택(콜라 245ml),디저트(단팥꽈배기))',
#     'review_text': '항상 맛있게 잘먹고있습니다.'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '며칠전 설연휴에 눈도 와서 라이더 배정 안 되어 캔슬되는 일이 있었습니다. 그래서 타 지점에 시켰는데... 전혀 다른 메뉴로 보이는 물건이 배달되더군요. \n이번에 다시 금호점에 시켜보고는 새삼 진짜 다른 걸 확인했습니다. \n\n진짜 금호점 맛초킹은 레벨이 다릅니다.\n오래오래 번창하세요.'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘먹었습니다 번창하세요'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '골드킹 콤보/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '레드킹 콤보/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '맛있게 먹었습니다.'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '배달 빠르고 맛있어요'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '느므느므 맛있는 핫후~후후'},
#    {'menus': '골드킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '골드킹은 맛초킹 정도의 감동은 없었네요. 뭐 그래도 맛있었습니다'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': 'BHC금호점은 역시 맛초킹이 최고의 선택인 듯'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공)),후라이드 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘먹었습니다 번창하세요'},
#    {'menus': 'HOT후라이드 콤보/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '심판받았지만 맛있습니다'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공))',
#     'review_text': '2-3년내에 먹은 배달치킨 중 가장 맛있었습니다. 튀김 바삭함이 살아있는 가운데 소스와 잘 버무려져 있었고, 무엇보다 소위 퍽퍽살이 촉촉했습니다. 리뷰이벤트 아니면 리뷰 거의 안 쓰는데, 이 정도면 추천 리뷰 남겨야겠다 싶어 적습니다.'},
#    {'menus': '후라이드 스틱/1(음료선택(서비스음료 미제공),소스(뿌링뿌링소스 추가))',
#     'review_text': '맛있어서 항상 1순위로 시켜용.^0^'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '닭이 크고 맛 좋았습니다.'},
#    {'menus': '뿌링클/1(음료선택(서비스음료 미제공))', 'review_text': '빠른 배달, 맛있는 치킨 좋아요'},
#    {'menus': 'HOT뿌링클 순살/1(음료선택(서비스음료 미제공)),후라이드 윙/1(음료선택(서비스음료 미제공))',
#     'review_text': '빠르게 배달해 주셔서 맛있게 잘 먹었습니다.  애들이 얘기해서 핫뿌링클을 주문했는데 제겐 좀 매운 감이 있었지만, 그래도 다들 잘 먹었어요. 감사합니다.'},
#    {'menus': '뿌링클/1(음료선택(콜라 355ml))', 'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '뿌링클순살/1(음료선택(서비스음료 미제공),디저트(뿌링치즈볼)),빨간소떡/1',
#     'review_text': '배달도 30분?정도 걸리고 넘 마싯서용..'},
#    {'menus': '양념치킨 콤보/1(음료선택(서비스음료 미제공)),뿌링클 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '너~~~무 맛있습니다!!'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '요청사항대로 배달해주셨고 맛있게 잘 먹었습니다!'},
#    {'menus': '(반반치킨)후라이드/양념/1(음료선택(서비스음료 미제공))',
#     'review_text': '전반적으로 괜찮습니다.'},
#    {'menus': '뿌링클 콤보/1(음료선택(서비스음료 미제공)),코카콜라 제로 1.25L./1',
#     'review_text': '바삭바삭 달콤 맛나요'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '고소하고 바삭바삭 맛있어요'},
#    {'menus': '뿌링클 스틱/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X)),달콤바삭치즈볼/1,(NEW) 뿌링클나쵸/1',
#     'review_text': '뿌링클 스틱으로 시켰는데 다리도 엄청 실하고 넘 맛있었어요ㅜㅜ 다른 지점에서 먹었을 때는 영계를 쓰는 건가 싶을 정도로 작은 다리여서 실망했었는데 여긴 진짜 찐으로 넘 맛있습니다,, 번창하세오'},
#    {'menus': 'HOT후라이드 콤보＋치즈볼/1(음료선택(콜라 355ml),요청사항(미체크 시 기본제공)(치킨무 X),요청사항(미체크 시 기본제공)(소스 X))',
#     'review_text': '맛있게 잘먹었어용'},
#    {'menus': 'HOT후라이드 콤보/1(음료선택(서비스음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X)),소주./1',
#     'review_text': '그냥완벽그자체 강츄'},
#    {'menus': '맛초킹 콤보/1(음료선택(서비스음료 미제공))', 'review_text': '맛있게 잘먹었습니다 번창하세요'},
#    {'menus': '레드킹순살/1(음료선택(콜라 245ml),디저트(케이준프라이))',
#     'review_text': '매콤하면서도 알싸한 레드킹 너무 맛있습니다!!!'},
#    {'menus': 'HOT후라이드 콤보/1(음료선택(서비스음료 미제공))',
#     'review_text': '모든메뉴가 다 맛있어서 항상 모먹을지 고민해요\n정말맛있어요'},
#    {'menus': '후라이드/1(음료선택(서비스음료 미제공)),양념치킨/1(음료선택(서비스음료 미제공))',
#     'review_text': '맛있게 잘 먹었습니다. 가까운 곳에 매장이 생기니 배달이 빨리 되어서 좋네요.'},
#    {'menus': 'HOT골드킹/1(음료선택(서비스음료 미제공),옵션(치킨무))',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': 'HOT후라이드/1(음료선택(서비스음료 미제공))', 'review_text': '빠른 배달, 맛있는 치킨 좋아요'},
#    {'menus': '바삭클/1(음료선택(서비스음료 미제공)),생맥주1000cc../1',
#     'review_text': '깔끔하게 초토화 시키고 있습니다.'},
#    {'menus': '맛초킹/1(음료선택(서비스음료 미제공)),코카콜라 제로 1.25L./1',
#     'review_text': '맛쵸킹 맛있습니다~~'},
#    {'menus': '맛초킹순살/1(음료선택(기본음료 미제공),요청사항(미체크 시 기본제공)(치킨무 X)),바삭클순살/1(음료선택(콜라 1.25L),요청사항(미체크 시 기본제공)(치킨무 X))',
#     'review_text': '일때문에 손도 못댓늗대 냄새가 벌써 위장을건드네 ... 잘먹겠습니다 ! ㅎ'},
#    {'menus': '후라이드/1', 'review_text': '핫후 너무 맛있네요!! 배달도 빨라요!!'},
#    {'menus': '뿌링클순살/1', 'review_text': '너무 맛있게 먹어서 사진이 없습니다;;'},
#    {'menus': 'HOT후라이드/1', 'review_text': '배달빠르고 바삭하고 맛있네요!!!'},
#    {'menus': '뿌링클 콤보/1', 'review_text': '배달빠르고맛있습니다'},
#    {'menus': '후라이드（반）＋뿌링치즈볼＋콜라245ml（제）/1', 'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '뿌링클＋치즈볼/1,후라이드 반／양념 반/1',
#     'review_text': '금호점 항상 이용해야겠어요~넘 서비스가 좋아요^^ 감사합니다.'},
#    {'menus': '레드킹순살/1(디저트(케이준프라이))',
#     'review_text': '오랜만에 레드킹 순살 먹었는데, 밥이랑 먹어도 맛있고 맥주랑도 잘 어울립니다. \n강추강추!!!'},
#    {'menus': '더블팝순살 후라이드/1,코카콜라 1.25L./1,양념소스/1',
#     'review_text': '바삭합니다 향신료 간이 된건지 저한테는 향과 간이 강하네요 ㅎㅎ 그래도 맛있게 잘 먹었습니다'},
#    {'menus': '뿌링클/1', 'review_text': '빠른배달, 맛있는 치킨 감사합니다'},
#    {'menus': 'HOT후라이드/1',
#     'review_text': 'bhc 중 핫후만 먹는 사람입니다. 동네에 있는 모든 bhc점 다 먹어봤는데, 바삭하면서도 매콤(핫!!)한 맛 제대로 나는 곳이네요\n\n지난번 bhc 쿠폰으로 시켜먹고 닭가슴살까지도 촉촉할수가... 하면서 먹었는데 이번에도 똑같이 바삭하고 닭가슴살까지 촉촉해서 만족도 최상이네요! 이 지점에서만 주문할랍니다!'},
#    {'menus': '뿌링클/1', 'review_text': '빠른배달, 맛있는 제품 좋아요'},
#    {'menus': '쏘마치/1',
#     'review_text': '치킨은 맛있는데 마늘튀긴거에서 곰팡이? 상한맛이 납니다ㅜㅜ 마늘튀긴게 메인이 메뉴인데ㅜㅜ 다들안시켜서 식자재관리가 안되나봅니다.'},
#    {'menus': '뿌링클/1', 'review_text': '역쉬 ~ 뿌링 뿌링  뿌링클 ~ 맛나용~'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1363980/'},
#  {'_id': '1357564',
#   'restaurant': '청년피자-행당점',
#   'reviews': [{'menus': '진짜감자피자/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '늘그렇듯이\n말이필요없습니다\n폭풍흡입이요'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가 (윙 2개),나만의 사색피자 선택 ((1/4)진짜게살피자),나만의 사색피자 선택 ((1/4)진짜감자피자),나만의 사색피자 선택 ((1/4)리얼페페로니),나만의 사색피자 선택 ((1/4)바질 콰트로치즈 피자),크러스트 추가 (치즈크러스트))',
#     'review_text': '너무 맛있어요 사색피자 추천해요'},
#    {'menus': '에그콘피자/1(해피메뉴 추가 (청년치즈떡볶이),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '에그콘이 부드럽고 달달한 게 매력이네요.'},
#    {'menus': '[신메뉴]진짜게살피자/1(해피메뉴 추가 (나폴리 토마토 스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '맛있게 잘먹겠습니다~🥰'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가 (시그니처 갈릭스파게티M),반반 오리지널L 피자 선택 1 ((반반)리얼페페로니),반반 오리지널L 피자 선택 2 ((반반)매드쉬림프),크러스트 추가 (통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '맛있게  먹었습니다'},
#    {'menus': '슈퍼슈프림/1(해피메뉴 추가 (나폴리 토마토 스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '청년피자 도우 진짜 맛있음.\n치즈 더 맛있어 진듯 합니다.\n오늘은 야채 토핑이 살짝 부족한면 있는듯 합니다.\n도우는 진짜 맛있음'},
#    {'menus': '[신메뉴]진짜게살피자/1(해피메뉴 추가 (청년치즈떡볶이),피자 사이즈 선택 (R사이즈 (1~2인)),크러스트 추가 (기본),기본 제공 품목 선택 (피클 제외),음료 추가 (코카콜라 제로 1.25L 추가))',
#     'review_text': '게살칩 바삭바삭 씹히는게 좋네요\n맛있어요'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본),기본 제공 품목 선택 (피클 제외))',
#     'review_text': '감자피자는 자주 먹어도 맛있네요ㅠㅠ 잘 먹었습니다 !'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (치즈크러스트))',
#     'review_text': '주문이 많은지 좀 오래 걸리긴했지만 피자 맛있어요'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가 (나폴리 토마토 스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '맛있고 양도 많습니다. 빠른 배송 감사 합니다'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본),기본 제공 품목 선택 (피클 제외),기본 제공 품목 선택 (핫소스 제외))',
#     'review_text': '맛있게 잘 먹었습니다\n다음에 또 주문할게요'},
#    {'menus': '야채피자/1(해피메뉴 추가 (나폴리 토마토 스파게티M),피자 사이즈 선택 (R사이즈 (1~2인)),크러스트 추가 (기본))',
#     'review_text': '맛있고 양도 많습니다 배달도 빠르고 리뷰이벤트 파스타 감사합니다'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '늘\n청년피자는\n옳아요\n매일먹고싶은맘이예요'},
#    {'menus': '에그콘피자/1(해피메뉴 추가 (청년치즈떡볶이),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '달달한 에그콘피자 좋아요. 굿.'},
#    {'menus': '리얼페페로니/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (마스카포네포테크런치엣지(크직바 크러스트)),피자토핑 추가 (옥수수 추가),피자토핑 추가 (올리브 추가),기본 제공 품목 선택 (청양마요소스 제외),기본 제공 품목 선택 (피클 제외),기본 제공 품목 선택 (파마산치즈 제외),기본 제공 품목 선택 (핫소스 제외))',
#     'review_text': 'good good good'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가 (나폴리 토마토 스파게티M),반반 오리지널L 피자 선택 1 ((반반)바질 콰트로치즈 피자),반반 오리지널L 피자 선택 2 ((반반)하와이안),크러스트 추가 (리치골드),기본 제공 품목 선택 (파마산치즈 제외),사이드메뉴 추가 (크리스피 핫윙 4개),음료 추가 (스프라이트 1.5L 추가))',
#     'review_text': '빠른 배달 많은 양 맛도 있고'},
#    {'menus': '빅파 불고기 피자/1(해피메뉴 추가 (윙 2개),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '너무 맛있습니다. 감사합니다.'},
#    {'menus': '멜팅 고구마 피자/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (R사이즈 (1~2인)),크러스트 추가 (기본))',
#     'review_text': '미야아아아아아옹ㅇ 야아아옹 야옹야옹'},
#    {'menus': '멜팅 고구마 피자/1(해피메뉴 추가 (나폴리 토마토 스파게티M),피자 사이즈 선택 (R사이즈 (1~2인)),크러스트 추가 (기본))',
#     'review_text': '올만에 피자먹었는데 맛있네요~'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본))',
#     'review_text': '늘\n맛있습니다\n감동입니디ㅡ'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가 (시그니처 갈릭스파게티M),나만의 사색피자 선택 ((1/4)진짜게살피자),나만의 사색피자 선택 ((1/4)진짜감자피자),나만의 사색피자 선택 ((1/4)슈퍼슈프림),나만의 사색피자 선택 ((1/4)바질 콰트로치즈 피자),크러스트 추가 (고구마체다크러스트))',
#     'review_text': '허거덩!!!너무 맛있어요!!!\n여러가지맛 시켜서 먹고 싶어서 사색피자 주문했는데 4가지\n맛 다 맛있었어요!!그리고 갈릭파스타도 진짜 강추요!!!면도 꼬들하고 갈릭맛도 진짜 최고임 ㅜㅠ또 주문하께요!!'},
#    {'menus': '오리지널 + 사이드메뉴(택1) + 음료1.25L/1(해피메뉴 추가 (청년치즈떡볶이),오리지널 피자 선택 (바질 콰트로치즈 피자 R),크러스트 추가 (기본),사이드메뉴 택1 (불고기크림파스타),음료(대) 선택 (코카콜라 1.25L),기본 제공 품목 선택 (피클 제외),기본 제공 품목 선택 (핫소스 제외))',
#     'review_text': '맛있게 잘 먹었습니다 피자도 파스타도 다 맛있었어요'},
#    {'menus': '메가모짜 치즈디쉬/1(해피메뉴 추가 (시그니처 갈릭스파게티M),피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (치즈디쉬엣지[크러스트 포함]))',
#     'review_text': '주문시간 7시58분\n도착시간 9시 23분\n27~40분 써있어서 시켰더니 1시간20분이 넘게 걸리네요\n치즈는 다 굳고 빵은 눅눅하고 다 식어빠지고\n이럴거면 장봐서 만드는게 빠르겠네요\n몇년동안 간간히 주문했는데 이제 다신 안할거 같아요'},
#    {'menus': '슈퍼슈프림/1(해피메뉴 추가 (나폴리 토마토 스파게티M),피자 사이즈 선택 (R사이즈 (1~2인)),크러스트 추가 (기본))',
#     'review_text': '피자도 스파게티도 다 맛있어요~^^\n세식구가 가볍게 먹기 딱 좋은 양이에요!'},
#    {'menus': '리얼치즈/1(피자 사이즈 선택 (L사이즈 (2~3인)),크러스트 추가 (기본),음료 추가 (코카콜라 1.25L 추가))',
#     'review_text': '항상 시켜 먹는 맛집!!!\n역시나 맛나게 먹었어요~'},
#    {'menus': '멜팅 고구마 피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본),피자토핑 추가(옥수수 추가),피자토핑 추가(파인애플 추가))',
#     'review_text': '고구마 피자 너무 맛있어요~잘먹겠습니다.'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(윙 2개),반반 오리지널L 피자 선택 1((반반/신메뉴)진짜게살피자),반반 오리지널L 피자 선택 2((반반)바질 콰트로치즈 피자),크러스트 추가(치즈크러스트),기본 제공 품목 선택(피클 제외),기본 제공 품목 선택(핫소스 제외))',
#     'review_text': '지금 신메뉴랑 전 신메뉴를 반반 시켜서 먹었어요 맛있었어요 바질도치즈도 좋아해서 바질콰트로치즈 맛있고 게가 가루?같은 느낌으로 바삭하게 올라가 있습니다 둘 다 맛있습니다'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),음료 추가(코카콜라 500ML 추가))',
#     'review_text': '지점마다 다른건가요 다른 지점에서 먹엇을땐 토미토 많았는데 여긴 없엇어요..'},
#    {'menus': '빅파 불고기 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹겠습니다'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '잘 먹었습니다 !!!!!'},
#    {'menus': '오리지널L + 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),오리지널피자 선택 1(리얼치즈 L),크러스트 추가 1(기본),오리지널피자 선택 2(야채피자 L),크러스트 추가 2(기본))',
#     'review_text': '맛있었습니당 감사합니다'},
#    {'menus': '반반 오리지널R/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 오리지널R 피자 선택 1((반반)리얼페페로니),반반 오리지널R 피자 선택 2((반반)빅파 불고기 피자),크러스트 추가(기본))',
#     'review_text': '적절한 양에 적절한 가격. 한끼 먹기에 좋았다. 파스타도 맛있었다.'},
#    {'menus': '리얼치즈/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었어요.\n근처 피저집 중 단연 최고💯'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가(나폴리 토마토 스파게티M),나만의 사색피자 선택((1/4)바질 콰트로치즈 피자),나만의 사색피자 선택((1/4)진짜감자피자),나만의 사색피자 선택((1/4)빅파 불고기 피자),나만의 사색피자 선택((1/4)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '반반 프리미엄L/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 프리미엄L 피자 선택 1((반반)메가모짜 치즈디쉬),반반 프리미엄L 피자 선택 2((반반)크리스피 직화바베큐),기본 제공 품목 선택(피클 제외),기본 제공 품목 선택(파마산치즈 제외),기본 제공 품목 선택(핫소스 제외))',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '반반 오리지널R/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 오리지널R 피자 선택 1((반반)진짜감자피자),반반 오리지널R 피자 선택 2((반반)할라불고기),크러스트 추가(기본))',
#     'review_text': '너무 만족스러워서 곧 재주문각입니다 ㅎ\n불고기에 할라피뇨가 매콤해서 맛있어요!!'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널L 피자 선택 1((반반)빅파 불고기 피자),반반 오리지널L 피자 선택 2((반반)리얼페페로니),크러스트 추가(치즈크러스트))',
#     'review_text': '넘  맛있게 먹다가 사진찍는걸 까먹어서\n중간에 찍었어요~~\n청년피자 도우 너무 쫄깃하고 맛있어요\n스파게티도 맛있게 잘 먹었어용 👍👍'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널L 피자 선택 1((반반)할라불고기),반반 오리지널L 피자 선택 2((반반)진짜감자피자),크러스트 추가(기본))',
#     'review_text': '맛있는데 가격도 저렴하서 너무 만족합니다 ㅎㅎ'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(윙 2개),반반 오리지널L 피자 선택 1((반반)에그콘피자),반반 오리지널L 피자 선택 2((반반)빅파 불고기 피자),크러스트 추가(기본))',
#     'review_text': '너무 맛있게 잘 먹었어요! 항상 감사합니다.'},
#    {'menus': '야채피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '야채피자 맛잇엉ㅅ요 감사합니다 \nㅏ담에 ㅋ도또 주문할게요 ㅎㅎ'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(윙 2개),반반 오리지널L 피자 선택 1((반반)할라불고기),반반 오리지널L 피자 선택 2((반반)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '청년피자는 항상 맛있습니다'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가(나폴리 토마토 스파게티M),나만의 사색피자 선택((1/4)바질 콰트로치즈 피자),나만의 사색피자 선택((1/4)진짜감자피자),나만의 사색피자 선택((1/4)리얼페페로니),나만의 사색피자 선택((1/4)할라불고기),크러스트 추가(기본))',
#     'review_text': '처음시켜봤는데 진짜 맛있어요!! 또 시킬께요!!\n사장님 피클감사합니다~♡'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 오리지널L 피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널L 피자 선택 2((반반)멕시칸맥쉬림프),크러스트 추가(기본))',
#     'review_text': '잘 먹었습니다. 감사합니다.'},
#    {'menus': '바삭한허니비/1(해피메뉴 추가(윙 2개),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '너무 맛있게 잘 먹었습니다🥰🥰'},
#    {'menus': '리얼페페로니/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(크림치즈크러스트),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '배달 빠르고 맛있습니다'},
#    {'menus': '슈퍼슈프림/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '따뜻하게 잘먹었어요'},
#    {'menus': '오리지널L + 오리지널L/1(오리지널피자 선택 1(야채피자 L),크러스트 추가 1(기본),오리지널피자 선택 2(리얼치즈 L),크러스트 추가 2(기본))',
#     'review_text': '배달도 엄청 빠르구 존맛탱구리구리에영'},
#    {'menus': '슈퍼슈프림/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '간만에 청년에서 시켰는데\n빵 부분이 너무 촉촉하고 맛있어요.\n도우가 너무 맛있게 변한듯 합니다.\n신기하게  피자끝부분이 너무 맛나서 즐거웠습니다.'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널L 피자 선택 1((반반)할라불고기),반반 오리지널L 피자 선택 2((반반)리얼치즈),크러스트 추가(기본),소스 추가(갈릭딥핑소스 추가),음료 추가(스프라이트 1.5L 추가))',
#     'review_text': '맛있어요 잘먹었습니당 스파게티는 싼만큼 양이 적었는데 오히려 딱 원하는 양이어서 좋았어요'},
#    {'menus': '바삭한허니비/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '새로운 메뉴로 도전해봤는데, 너무 맛있네용👍\n해피메뉴로 주문한 스파게티도 잘 먹었습니다😘'},
#    {'menus': '반반 오리지널R/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 오리지널R 피자 선택 1((반반)빅파 불고기 피자),반반 오리지널R 피자 선택 2((반반)할라불고기),크러스트 추가(기본))',
#     'review_text': '갑자기 피자 생각이 나서 주문했는데, 알찬구성에 맛나는 소스까지 함께 챙겨주셔서 잘 먹었습니다. 다음에 또 시킬께용'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '감자피자가 인기 많은 이유가 있었네요~  맛있어요~ \n도우도 맛나서 다른거 안찍어먹어도 돼구요~ \n함께한 떡볶이도  맛있었어요~'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가(윙 2개),나만의 사색피자 선택((1/4)진짜감자피자),나만의 사색피자 선택((1/4)리얼페페로니),나만의 사색피자 선택((1/4)할라불고기),나만의 사색피자 선택((1/4)매드쉬림프),크러스트 추가(리치골드),소스 추가(피클 추가),소스 추가(핫소스 추가)),핫소스/3',
#     'review_text': '진짜 개맛있습니다 진짜.. 믿고 먹어요'},
#    {'menus': '빅파 불고기 피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(치즈크러스트))',
#     'review_text': '피자좋아하는 아이와 맛있게 잘 먹었습니다!'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널L 피자 선택 1((반반)멜팅 고구마 피자),반반 오리지널L 피자 선택 2((반반)리얼페페로니),크러스트 추가(기본),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '맛있게 잘 막었습니다!'},
#    {'menus': '나만의 사색피자L/1(나만의 사색피자 선택((1/4)바질 콰트로치즈 피자),나만의 사색피자 선택((1/4)빅파 불고기 피자),나만의 사색피자 선택((1/4)슈퍼슈프림),나만의 사색피자 선택((1/4)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '하와이안/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '하와이안 피자 최고! 파스타 맛있었다~'},
#    {'menus': '빅파 불고기 피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본),음료 추가(코카콜라 1.25L 추가))',
#     'review_text': '토핑이 듬뿍이고 빵이 부드럽고 청양마요소스가 완전 킥이에요'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '신메뉴라고 해서 가감히 선택!  ㅎㅎ 맛있었어요. \n치즈도 맛있고. 빵도 쫄깃하고 다음에도 오케이입니다'},
#    {'menus': '에그콘피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본)),청양마요소스/1',
#     'review_text': '에그콘 피자가 맛있어서 맨날 생각나요\n시그니처 갈릭 파스타도 너무 맛있는데 본품으로 안 파시는건가요'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(청년치즈떡볶이),반반 오리지널L 피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널L 피자 선택 2((반반)진짜감자피자),크러스트 추가(통치즈크러스트(더욱 꽉 찬)),사이드메뉴 추가(미트소스스파게티 추가))',
#     'review_text': '맛있게잘먹었습니다 치즈크러스트꼭추가추천해요'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '신메뉴라서 주문해봤는데 대박 강추입니다.!! 맛있게 먹었습니다ㅎㅎ'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가(나폴리 토마토 스파게티M),나만의 사색피자 선택((1/4)빅파 불고기 피자),나만의 사색피자 선택((1/4)슈퍼슈프림),나만의 사색피자 선택((1/4)리얼페페로니),나만의 사색피자 선택((1/4)멜팅 고구마 피자),크러스트 추가(기본),음료 추가(코카콜라 1.25L 추가))',
#     'review_text': '잘 먹었어요~~~~'},
#    {'menus': '반반 오리지널R/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널R 피자 선택 1((반반)리얼페페로니),반반 오리지널R 피자 선택 2((반반)빅파 불고기 피자),크러스트 추가(기본),음료 추가(코카콜라 제로 500ML 추가))',
#     'review_text': '사진을 못 찍었어요 ㅠㅠ.... 피자 안 좋아하지만 간만에 생각나서 시켜본건데.. 정말 정말 맛있습니다!! 감사합니다!!'},
#    {'menus': '할라불고기/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),코카콜라 제로 500ML/1',
#     'review_text': '설숲 피크닉 와서 피자 시켰는데 넘 맛있구 배달도 빨리 와서 따뜻하게 먹었어요🤍🤍'},
#    {'menus': '슈퍼슈프림/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),갈릭딥핑소스/2',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널L 피자 선택 1((반반)진짜감자피자),반반 오리지널L 피자 선택 2((반반)[신메뉴]바질 콰트로치즈 피자),크러스트 추가(기본),음료 추가(코카콜라 제로 500ML 추가)),멜팅 고구마 피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '감자가 쫄깃하고 맛있어요! 고구마피자는 매운 것을 못먹는 아이들 먹으려고 구매했는데, 베이스로 발려진 붉은색 토마토 소스가 시각적으로 맵게 느껴졌는지 실제로 매운맛을 느끼는건지 모르겠지만 맵다면서 안먹네요ㅋ(어른들 먹기엔 매운 맛 안느껴져요) 덕분에 어른들이 피자를 푸짐하게 먹었습니다~~'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가(시그니처 갈릭스파게티M),나만의 사색피자 선택((1/4)바질 콰트로치즈 피자),나만의 사색피자 선택((1/4)슈퍼슈프림),나만의 사색피자 선택((1/4)하와이안),나만의 사색피자 선택((1/4)멜팅 고구마 피자),크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '지난 번 맛있어서 두번째 주문인데 역시 맛있네요!제 입맛에는 하와이안과 고구마 맛이 강추!'},
#    {'menus': '에그콘피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '토핑이 달고 부드러워요. 서비스로 주신 떡볶이가 귀엽고 맛있어요.'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '피자 본품은 감자도 많고 괜찮은데 \n배달이 1시간 넘게 걸려서 다 식어서 도착했어요.\n배달이 늦어 아쉽네요.'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(청년치즈떡볶이),반반 오리지널L 피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널L 피자 선택 2((반반)에그콘피자),크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '맛있어서 또 시켜요 근데 해피메뉴에 있는 치즈떡볶이 맛있는데 크기가 작아서 크게 먹고싶어서 사이드를 찾아보니 없더라구요.. 정식 메뉴가 아닌가봐요 그래도 잘 먹었습니다'},
#    {'menus': '메가쉬림프 갈릭크런치/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭크런치엣지[크러스트 포함]))',
#     'review_text': '너무 맛있게 잘 먹었습니다🥰🥰'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널L 피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널L 피자 선택 2((반반)슈퍼슈프림),크러스트 추가(기본))',
#     'review_text': '잘먹었습니다    😀'},
#    {'menus': '[신메뉴]치즈수플레 미트파이 피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(치즈수플레엣지[크러스트 포함]),사이드메뉴 추가(알리오올리오파스타 추가))',
#     'review_text': '피자도 스파게티도 맛있어요 ^^'},
#    {'menus': '반반 오리지널R/1(해피메뉴 추가(청년치즈떡볶이),반반 오리지널R 피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널R 피자 선택 2((반반)에그콘피자),크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '맛있게 잘 먹었어요.'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '핫소스 등 소스류는 원래 안주시나요..ㅜㅜ'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '도우가 바삭하고 치즈랑 토핑도 많이\n있어요'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 오리지널L 피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널L 피자 선택 2((반반)리얼페페로니),크러스트 추가(기본))',
#     'review_text': '따뜻하게 배달해 주셔서 감사합니다'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '오랜만에인데 맛있게 잘먹었어요 떡볶이 학교 앞에서 파는 그맛?이에요 저게 500원 양이라 그런데 메뉴에 있는건 더 양 많겠죠 찍어 먹어도 맛있음 글구 50분 예상시간 받았는데 20분만에'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),사이드메뉴 추가([신메뉴]그릴드 와일드 통다리 (양념바베큐) 1개 추가))',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '나만의 사색피자L/1(해피메뉴 추가(윙 2개),나만의 사색피자 선택((1/4)슈퍼슈프림),나만의 사색피자 선택((1/4)리얼페페로니),나만의 사색피자 선택((1/4)하와이안),나만의 사색피자 선택((1/4)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '오리지널+[국내산]오븐베이크치킨+음료/1(해피메뉴 추가(청년치즈떡볶이),오리지널 피자 선택(할라불고기 L),크러스트 추가(기본),음료(대) 선택(코카콜라 제로 1.25L))',
#     'review_text': '헐 제 주문 기다린 것처럼 샤워하고 나오니까 배달 완료\n손대기 전 사진 찍습니다!^^ 감사히 잘 먹겠습니다.'},
#    {'menus': '오리지널 + 청피스틱 세트/1(해피메뉴 추가(나폴리 토마토 스파게티M),오리지널 피자 선택(할라불고기 L),크러스트 추가(치즈크러스트),청피스틱 선택(고구마크림치즈스틱),음료 선택(코카콜라 제로 500ML),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '맛나게 잘 먹었습니다~!'},
#    {'menus': '진짜감자피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '만족스럽게 아주 잘 먹었습니다. ^^'},
#    {'menus': '에그콘피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '좋아하던 피자입니다. 한동안 배달이 되지 않아서 못 먹다가 배달 된다길래 얼른 주문했어요. 역시 달달하고 맛있어요. 떡볶이도 조랭이떡이 쫀득하고 맛있었어요.'},
#    {'menus': '에그콘피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),음료 추가(코카콜라 제로 500ML 추가))',
#     'review_text': '에그콘피자 너무 맛있어서 이틀 전에 시키고 또 시켜요\n그리고 시그니처 갈릭 파스타 너무 맛있어요ㅜㅜ\n배달도 넘 빠름'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(시그니처 갈릭스파게티M),반반 오리지널피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널피자 선택 2((반반)에그콘피자),크러스트 추가(기본),음료 추가(코카콜라 제로 500ML 추가))',
#     'review_text': '청년피자 에그콘 너무 좋아해서 오랜만에 시켜봤는데\n역시 너무 맛있고  갈릭스파게티 왜이렇게 맛있죠 면익힘도도 최고에요 다음에도 주문하겠습니다'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널피자 선택 1((반반)하와이안),반반 오리지널피자 선택 2((반반)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '크리스피 직화바베큐/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(마스카포네포테크런치엣지[크러스트 포함]),사이드메뉴 추가(나초치즈감자튀김 추가))',
#     'review_text': '너무 맛있어요 잘 먹었습니다😋'},
#    {'menus': '멜팅 고구마 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),피자토핑 추가(페페로니 추가(20개)),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '처음 주문했는데 맛있게 잘 먹었습니다'},
#    {'menus': '오리지널 + 청피스틱 세트/1(해피메뉴 추가(시그니처 갈릭스파게티M),오리지널 피자 선택([신메뉴]바질 콰트로치즈 피자 L),크러스트 추가(기본),청피스틱 선택(갈릭도그스틱),음료 선택(코카콜라 제로 500ML))',
#     'review_text': '맛나게 잘 먹었습니다~!'},
#    {'menus': '토핑농장/1(해피메뉴 추가(나폴리 토마토 스파게티M),크러스트 추가(치즈크러스트))',
#     'review_text': '엄마가 제일 좋아하세요. 맛있게 잘 먹었어요!'},
#    {'menus': '토핑농장/1(해피메뉴 추가(나폴리 토마토 스파게티M),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '멜팅 고구마 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '맛있습니다 맛있습니다'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)리얼페페로니),크러스트 추가(기본))',
#     'review_text': '개존맛 맛있습니다!!'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널피자 선택 1((반반)하와이안),반반 오리지널피자 선택 2((반반)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '멜팅 고구마 피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),진짜감자피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),멜팅 고구마 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),코카콜라 제로 1.25L/1',
#     'review_text': '아이고잘먹었습니다요!'},
#    {'menus': '[신메뉴]바질 콰트로치즈 피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '신메뉴여서 시켜봤는데 맛있어요~치즈가 듬뿍 있어서 와인이랑도 잘 어울립니다 도우도 쫄깃쫄깃 아주 맛나요'},
#    {'menus': '멕시칸맥쉬림프/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(치즈크러스트),음료 추가(스프라이트 1.5L 추가))',
#     'review_text': '맛있게 잘 먹었어요'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널피자 선택 1((반반)하와이안),반반 오리지널피자 선택 2((반반)멜팅 고구마 피자),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '멜팅 고구마 피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '양도 많고 넘 맛있어요! 스파게티가 넘 맛있어서 좀만 더 양이 많았더라면🥲 앞으로 자주 시켜먹을듯요! 근래 먹어본 고구마피자 중 제일 맛있었어요👍🏻🤗😋'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)에그콘피자),반반 오리지널피자 선택 2((반반)진짜감자피자),크러스트 추가(기본),사이드메뉴 추가(미트소스스파게티 추가))',
#     'review_text': '맛있게 잘 먹었습니당 😆😆'},
#    {'menus': '오리지널 + 청피스틱 세트/1(해피메뉴 추가(나폴리 토마토 스파게티M),오리지널 피자 선택(할라불고기 L),크러스트 추가(치즈크러스트),청피스틱 선택(갈릭도그스틱),음료 선택(코카콜라 제로 500ML),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '맛나게 잘 먹었습니다~!'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)[신메뉴]바질 콰트로치즈 피자),반반 오리지널피자 선택 2((반반)[신메뉴]바질 콰트로치즈 피자),크러스트 추가(치즈크러스트))',
#     'review_text': '사진 남길 시간도 없이 맛있게 먹었어요 ^^;'},
#    {'menus': '프리미엄 + 청피스틱 세트/1(프리미엄 피자 선택([신메뉴]치즈수플레 미트파이 피자 R),피자토핑 추가(치즈 추가(80g)),청피스틱 선택(갈릭도그스틱),음료 선택(코카콜라 제로 1.25L))',
#     'review_text': '맛있어요.\n  치즈가 너무너무 맛있어요'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(윙 2개),반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)할라불고기),크러스트 추가(기본))',
#     'review_text': '배달도 빠르고 맛있었습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)슈퍼슈프림),크러스트 추가(기본),피자토핑 추가(올리브 추가),사이드메뉴 추가(베이컨까르보나라 추가))',
#     'review_text': '오늘두 맛있게 잘 먹었습니당😀😀'},
#    {'menus': '에그콘피자/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹었습니다!'},
#    {'menus': '야채피자/1(해피메뉴 추가(청년치즈떡볶이),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '너무 맛있습니다. 감사합니다.'},
#    {'menus': '슈퍼슈프림/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '쿠폰 할인하길래 기대없이 시켜봤는데 너무 맛있네요~ 도우도 많이 두껍지않고, 빵 가장자리 잘 안먹는데 여긴 바삭하니 맛있어오. 리뷰이벤트 없이도 후기쓰게 만드네요. 맛있습니다~ 담에 다른맛도 시켜먹어봐야겠어요.'},
#    {'menus': '오리지널L+[국내산]오븐베이크치킨(택1)+음료/1(해피메뉴 추가(나폴리 토마토 스파게티M),오리지널L 피자 선택(바삭한허니비 L),크러스트 추가(치즈크러스트),치킨 선택([국내산]오븐베이크치킨),음료(대) 선택(코카콜라 제로 1.25L))',
#     'review_text': '맛있게 잘먹었습니다 ㅎㅎ'},
#    {'menus': '오리지널L + 프리미엄L/1(오리지널피자 선택 1(진짜감자피자 L),크러스트 추가 1(기본),프리미엄피자 선택 2([신메뉴]뉴욕비프 갈릭크런치 L),음료 추가(코카콜라 1.25L 추가),음료 추가(코카콜라 제로 1.25L 추가)),매드쉬림프/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '배달 빨라요\n맛있어용'},
#    {'menus': '[신메뉴]메가쉬림프 갈릭크런치/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(갈릭크런치엣지[크러스트 포함]))',
#     'review_text': '크게 기대 안하고 주문했는데 기대이상이네요\n보통 느끼해서 2조각먹고 말았는데\n첨으로 3조각 먹었네요\n같이주신 알리오 올리오가 좀 너무 단거 빼고는\n아주 만족했습니다'},
#    {'menus': '바삭한허니비/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(고구마체다크러스트))',
#     'review_text': '배달속도도 빠르규 맛도 조아용'},
#    {'menus': '오리지널L+[국내산]오븐베이크치킨(택1)+음료/1(해피메뉴 추가(윙 2개),오리지널L 피자 선택(에그콘피자 L),크러스트 추가(치즈크러스트),치킨 선택([국내산]오븐베이크치킨),음료(대) 선택(코카콜라 제로 1.25L))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '오리지널L+[국내산]오븐베이크치킨(택1)+음료/1(해피메뉴 추가(청년치즈떡볶이),오리지널L 피자 선택(바삭한허니비 L),크러스트 추가(치즈크러스트),치킨 선택([국내산]오븐베이크치킨),음료(대) 선택(코카콜라 제로 1.25L))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '에그콘피자/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(치즈크러스트),소스 추가(핫소스 추가))',
#     'review_text': '피자도 파스타도 다 맛있네요'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': 'ㅠㅠ이제 리뷰이벤트 없어졋다고하네요. 그래도 마지막까지 챙겨주셔서 감사합니다 잘먹엇어요!'},
#    {'menus': '[신메뉴]메가쉬림프 갈릭크런치/1(해피메뉴 추가(나폴리 토마토 스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭크런치엣지[크러스트 포함]))',
#     'review_text': '배달 빠르고 맛있어요'},
#    {'menus': '[신메뉴]메가쉬림프 갈릭크런치/1(해피메뉴 추가(시그니처 갈릭스파게티M),피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭크런치엣지[크러스트 포함])),갈릭딥핑소스/1,홍마요소스/1',
#     'review_text': '한번먹고 맛있어서 또 시켰어요\n최애피자가 되버렸네요'},
#    {'menus': '반반 오리지널L/1(해피메뉴 추가(나폴리 토마토 스파게티M),반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)바삭한허니비),크러스트 추가(치즈크러스트),피자토핑 추가(치즈 추가(80g)),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)달콤한나의고구마),반반 오리지널피자 선택 2((반반)에그콘피자),크러스트 추가(기본)),갈릭딥핑소스/2,스프라이트 1.5L/1',
#     'review_text': '야구보면서 먹으려고 시켰는데 피자더 맛있고 야구도 이기고 좋아요~|~'},
#    {'menus': '반반 프리미엄L/1(반반 프리미엄피자 선택 1((반반)[신메뉴]메가쉬림프 갈릭크런치),반반 프리미엄피자 선택 2((반반)[신메뉴]뉴욕비프 갈릭크런치))',
#     'review_text': '맛있게 잘 먹었어용🤭'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)리얼페페로니),반반 오리지널피자 선택 2((반반)달콤한나의고구마),크러스트 추가(기본),피자토핑 추가(옥수수 추가),소스 추가(피클 추가))',
#     'review_text': '맛있어요 ~잘 먹었습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)매드쉬림프),크러스트 추가(기본)),로제베이컨스파게티/1',
#     'review_text': '피자 맛있고 양도 좋아요!^^'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '도우가 정말 맛있고 치즈도 맛있습니다. 배달도 빨리와서 좋았어요'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': 'ㅠㅠ한조각 한조각 사라질때마다 나의마음은~~~ 너무 맛잇습니다'},
#    {'menus': '슈퍼슈프림/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본),음료 추가(코카콜라 1.25L 추가))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)리얼페페로니),크러스트 추가(기본))',
#     'review_text': '배달도 빠르고 맛있습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)리얼페페로니),크러스트 추가(치즈크러스트))',
#     'review_text': '완전 맛있어여\n치즈도 정말 맛있어여'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '지리네요 크러스트도 기본인데 소스 없이 먹어도 맛있어요'},
#    {'menus': '에그콘피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),피자토핑 추가(마요네즈 추가))',
#     'review_text': '에그콘피자 맛있게 잘 먹었습니다!'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)리얼페페로니),크러스트 추가(고구마체다크러스트),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '처음 시켜봤는데 정말 맛있어요👍'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '맛있게 잘 먹었습니다\n다음에 또 주문할게요'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)리얼불고기),크러스트 추가(기본)),코카콜라 제로 1.25L/1',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)매드쉬림프),반반 오리지널피자 선택 2((반반)할라불고기),크러스트 추가(기본)),청년너겟 15개/1',
#     'review_text': '배달도 빠르고 맛있었습니다'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(치즈크러스트))',
#     'review_text': '맛있고 배달도 빨라요!'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)리얼불고기),반반 오리지널피자 선택 2((반반)리얼페페로니),크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '존맛탱 늘 잘시켜먹어요'},
#    {'menus': '하와이안/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(고구마체다크러스트))',
#     'review_text': '맛있았습니다ㅎㅎㅎㅎ'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '정말 맛있게 잘 먹었습니다~🤗🤗'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)에그콘피자),크러스트 추가(기본))',
#     'review_text': '처음으로 반반 주문해봤는데 맛있었어요!\n잘 먹었습니다 사장님:)'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)달콤한나의고구마),크러스트 추가(기본))',
#     'review_text': '배달이 엄청 빨리왔어요!!\n청년피자 우유도우 넘 맛있어서 꼬다리까지 맛있게 먹어요\n토핑도 실하게 올라가서 피자 맛집으로 인정\n이벤트로 온 파스타도 꿀맛이에요'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)할라불고기),크러스트 추가(기본))',
#     'review_text': '배달도 빠르고 맛있었습니다'},
#    {'menus': '바삭한허니비/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),할라피뇨/1,피클/1',
#     'review_text': '달지만 맛있어요.\n리뷰이벤트로 주는 스파게티 양이 넘 적어서 아쉬워요.\n소스는 남던데 면을 더 넣어주시면 좋겠어요.'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '토핑도 많고 맛있어요'},
#    {'menus': '메가모짜 치즈디쉬/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(치즈디쉬엣지[크러스트 포함]),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '처음 먹어봤는데 맛있어요\n전반적으로 치즈가 많이 들어있고 앞쪽부터 중간까지는 불고기피자 베이스인 것 같네요 꽁다리쪽은 질기지 않고 기분좋은 짭조름함과 바바삭함의 조화가 만족스러웠습니다 중간중간 씹히는 말랑한 토마토랑 전반적인 후추향도 맛있었어요\n 다만 재료가 재료인 만큼 살짝 느끼한 감은 있습니다 따라서 핫소스랑 같이 먹으면 더 맛있을 것 같아요\n 리뷰이벤트로 주신 떡볶이도 야무지네요'},
#    {'menus': '씨푸드 콘 바스켓/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭치즈콘엣지[크러스트 포함]))',
#     'review_text': '잘먹었습니다 제로콜라서비스도 감사합니다 ㅎㅎ'},
#    {'menus': '리얼치즈/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본)),치즈 추가(80g)/1',
#     'review_text': '항상 치즈츠가해서 먹는데 맛나요 굿!!'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)리얼페페로니),크러스트 추가(기본))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '따뜻하다못해 뜨겁게 잘먹엇어요%~~ 배달도 빠르고 좋앗습니다'},
#    {'menus': '슈퍼슈프림/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본),피자토핑 추가(마요네즈 추가),소스 추가(갈릭딥핑소스 추가),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '정말 맛있습니다 추천드려요'},
#    {'menus': '토핑농장/1(크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '배송 상태도 좋고\n맛도 훌륭\n강추!'},
#    {'menus': '프리미엄L + 청피스틱 세트/1(프리미엄L 피자 선택([신메뉴]메가쉬림프 갈릭크런치 L),청피스틱 선택(갈릭도그스틱),음료 선택(스프라이트 1.5L),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '맛나게 잘 먹었습니다~!'},
#    {'menus': '[신메뉴]메가쉬림프 갈릭크런치/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭크런치엣지[크러스트 포함])),갈릭딥핑소스/2,콘소메딥핑소스/1,파마산치즈/1',
#     'review_text': '맛있어요 ! 배달도 빨라요'},
#    {'menus': '프리미엄L + 사이드메뉴(택1) + 음료1.25L/1(프리미엄L 피자 선택([신메뉴]메가쉬림프 갈릭크런치 L),사이드메뉴 택1(핫윙봉 5개),음료(대) 선택(코카콜라 제로 1.25L),소스 추가(갈릭딥핑소스 추가))',
#     'review_text': '🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏 🙏'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)야채피자),크러스트 추가(고구마체다크러스트),피자토핑 추가(치즈 추가(80g)),사이드메뉴 추가(미트소스스파게티 추가))',
#     'review_text': '너무너무 맛있어요.  잘 먹었습니다.'},
#    {'menus': '반반 프리미엄L/1(반반 프리미엄피자 선택 1((반반)[신메뉴]메가쉬림프 갈릭크런치),반반 프리미엄피자 선택 2((반반)씨푸드 콘 바스켓),피자토핑 추가(치즈 추가(80g)),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '살짝 찌부됬지만 맛있게먹었내요'},
#    {'menus': '에그콘피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(고구마체다크러스트))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '반반 프리미엄L/1(반반 프리미엄피자 선택 1((반반)씨푸드 콘 바스켓),반반 프리미엄피자 선택 2((반반)메가모짜 치즈디쉬),음료 추가(코카콜라 제로 1.25L 추가))',
#     'review_text': '너무 맛있어요~\n또 주문할게요 잘 먹었습니다 ㅎㅎ'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)할라불고기),크러스트 추가(기본)),코카콜라 제로 1.25L/1',
#     'review_text': '배달도 빠르고 맛있었습니다'},
#    {'menus': '에그콘피자/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(기본))',
#     'review_text': '배달이 빨리와서 따뜻한 상태에서 너무 맛있게 먹었습니다!'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '진짜 오랜만에 피자 먹었는데 역시 피자 도우가 훨씬 고급지게 바뀐게 다른프랜차이즈 피자집온줄 알았어요 진짜 엄청 잘먹었네요 일하느라 타이밍 잡기가 쉽지 읺았지만 오랜만에 행당지점 피자 먹어서 좋았었습니다'},
#    {'menus': '반반 프리미엄L/1(반반 프리미엄피자 선택 1((반반)[신메뉴]메가쉬림프 갈릭크런치),반반 프리미엄피자 선택 2((반반)[신메뉴]뉴욕비프 갈릭크런치),소스 추가(핫소스 추가))',
#     'review_text': '할명수 보고 주문해봤는데\n조금 다르긴 했지만 맛있었어요'},
#    {'menus': '진짜감자피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '이전에 먹는 거 보다 토핑 얇아졌고 전체적으로 재료를 쓰는 게 부족했어요,정말 아쉬웠어요.그 전에 비해서 피자가 많이 바뀌었어요.\n유일한 장점은 요리과배송 속도가 정말 빠릅니다.'},
#    {'menus': '야채피자/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본),피자토핑 추가(옥수수 추가),피자토핑 추가(올리브 추가))',
#     'review_text': '맛있고 양도 많습니다. 리뷰이벤트 서비스 까지 감사합니다'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1((반반)진짜감자피자),반반 오리지널피자 선택 2((반반)슈퍼슈프림),크러스트 추가(치즈크러스트),음료 추가(코카콜라 1.25L 추가))',
#     'review_text': '청년피자 역시 맛있네요\n치즈크러스트까지 추가해서 정말 맛있게  먹었어요'},
#    {'menus': '[신메뉴]메가쉬림프 갈릭크런치/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(갈릭크런치엣지[크러스트 포함]))',
#     'review_text': '잘 먹었어요 또 주문할께요'},
#    {'menus': '[신메뉴]메가쉬림프 갈릭크런치/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭크런치엣지[크러스트 포함]),소스 추가(갈릭딥핑소스 추가)),갈릭딥핑소스/2',
#     'review_text': '진짜 진짜 맛있어요\n맛있다고 한50번 말하면서 먹었네요\n파스타도 맛있게 먹었어요'},
#    {'menus': '씨푸드 콘 바스켓/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭치즈콘엣지[크러스트 포함]))',
#     'review_text': '맛있게 먹었습니디!~~~'},
#    {'menus': '리얼페페로니/1(피자 사이즈 선택(L사이즈 (2~3인)),크러스트 추가(기본))',
#     'review_text': '항상 잘먹고갑니다'},
#    {'menus': '반반 프리미엄L/1(반반 프리미엄피자 선택 1((반반)[신메뉴]뉴욕비프 갈릭크런치),반반 프리미엄피자 선택 2((반반)크리스피 직화바베큐))',
#     'review_text': '맛있게 잘 먹었습니다!'},
#    {'menus': '[추천]프리미엄R ＋ 청피스틱 세트/1(프리미엄R 피자 선택(달콤한나의고구마 R),크러스트 추가(기본),청피스틱 선택([추천]청피맥앤치즈스틱),음료 선택(코카콜라 1.25L))',
#     'review_text': '너무너무 맛있어요♡\n배송도 빠르고'},
#    {'menus': '[신메뉴]메가모짜 치즈디쉬/1(피자 사이즈 선택(L사이즈 （2~3인）),크러스트 추가(기본)),코카콜라 1.25L/1',
#     'review_text': '배달옆으로가서 가져옴 ㅠ 파스타맛있는데 양너무적음... \n피자 토핑어디에는 많고 어디에는 아에없고... 여러므로 아쉽 ㅠ\n맛은갠춘 토마토좀 호불호좀갈릴듯'},
#    {'menus': '[인기]진짜감자피자/1(피자 사이즈 선택(L사이즈 （2~3인）),크러스트 추가(기본))',
#     'review_text': '언제나처럼 맛있게 잘 먹었습니다~~\n떡볶이도 매력있는 맛이네요 🤗\n\n그런데 피자 밑에 깔리는 유산지가 없이 왔어요\n정책상 포장방침이 바뀐거라면 어쩔 수 없지만 이런 경우는 처음봐서요'},
#    {'menus': '[인기]진짜감자피자/1(피자 사이즈 선택(R사이즈 （1~2인）),크러스트 추가(기본),소스 추가(콘소메딥핑소스 추가),소스 추가(피클 추가))',
#     'review_text': '토핑도 담백하게맛있구 도우도 안딱딱해서 먹기좋아요'},
#    {'menus': '야채피자/1(피자 사이즈 선택(L사이즈 （2~3인）),크러스트 추가(기본))',
#     'review_text': '도우가 확실히 맛있네요😋  L 2-3인용 혼자 다 먹을수있는양이예요 주문시 참고하세요'},
#    {'menus': '[인기]진짜감자피자/1(피자 사이즈 선택(L사이즈 （2~3인）),크러스트 추가(기본))',
#     'review_text': '배달 빠르고 맛있습니다'},
#    {'menus': '리얼불고기/1(피자 사이즈 선택(R사이즈 （1~2인）),크러스트 추가(통치즈크러스트(더욱 꽉 찬)))',
#     'review_text': '통모짜크러스트 꼭 드세요 존맛\n배달도 빠르고 잘먹었습니다!'},
#    {'menus': '[인기]진짜감자피자/1(피자 사이즈 선택(R사이즈 （1~2인）),크러스트 추가(치즈크러스트),피자토핑 추가(올리브 추가))',
#     'review_text': '왕맛있ㅇㅓ요😀😀😀'},
#    {'menus': '[인기]진짜감자피자/1(피자 사이즈 선택(L사이즈 （2~3인）),크러스트 추가(기본))',
#     'review_text': '드디어 다시 오픈하셔서 반가운 마음으로 주문했습니다\n이번에 바뀐 도우의 맛이 어마무시 하네요..피자가 이럴 수도 있구나 싶어서 깜짝놀랐습니다\n단지 그냥 피자 한판이 아니라 기분좋은 식사를 즐기는 기분이 들었어요\n덕분에 가족들과 맛있는 저녁을 보냈습니다.\n\n많은 분들이 이런 피자를 경험했으면 하는 마음으로 리뷰를 남기며,\n저녁 메뉴를 고민 중인 당신\n주저없이 다이브 하셔도 좋습니다👍'},
#    {'menus': '야채피자/1(피자 사이즈 선택(L사이즈 （2~3인）),크러스트 추가(기본))',
#     'review_text': '맛있고 양도 많습니다 리뷰이벤트 서비스 감사합니다'},
#    {'menus': '[인기]진짜감자피자/1(피자 사이즈 선택(R사이즈 （1~2인）),크러스트 추가(기본),음료 추가(코카콜라 500ML 추가))',
#     'review_text': '맛잇게 잘먹엇습니다'},
#    {'menus': '[추천]오리지널L ＋ 청피스틱 세트/1(오리지널L 피자 선택(슈퍼슈프림 L),크러스트 추가(기본),청피스틱 선택([신메뉴]갈릭도그스틱),음료 선택(코카콜라 1.25L))',
#     'review_text': '맛있게잘먹었습니다 수고하세요'},
#    {'menus': '반반 오리지널L/1(반반 오리지널피자 선택 1(（반반）리얼불고기),반반 오리지널피자 선택 2(（반반）리얼페페로니),크러스트 추가(통치즈크러스트(더욱 꽉 찬))),청양마요소스/1',
#     'review_text': '믿고먹는 청년피자b 배달도 완전 빠르고 너무 맛있게 먹었어요'},
#    {'menus': '리얼불고기/1(피자 사이즈 선택(R사이즈 （1~2인）),크러스트 추가(기본),소스 추가(청양마요소스 추가),소스 추가(홍마요소스 추가))',
#     'review_text': '오랜만에 주문했는데 바뀌었네요? 씬이 아니더라고요\n그매력이 사라졌지만 고소하니 맛있었어요 재료가 예전 보단 덜 해졌지만 만족했어요 첫끼라.. 스파게티 \n잘 먹었어요 굿'},
#    {'menus': '[인기]씨푸드 콘 바스켓/1(피자 사이즈 선택(R사이즈 (1~2인)),크러스트 추가(갈릭치즈콘엣지(크러스트 포함)))',
#     'review_text': '역시 맛있어욭 근뎅 이번에 배달이 좀 쏠려서왔어요 ㅜㅜ'},
#    {'menus': '[인기]고구마크림치즈스틱/1,핫윙봉 5개/1,피클/1',
#     'review_text': '고구마크림치즈스틱 진짜 맛있다고 들었는데 진짜 맛있어요..🤤 앞으로 여기서만 먹을거에요!!'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1357564/'},
#  {'_id': '1436357',
#   'restaurant': '호식이두마리치킨-신당점',
#   'reviews': [{'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택 ([신메뉴]맵시크(hot)),플라윙 소스선택 (간장),기본음료선택 (코카콜라 제로 500ml 변경),사이드 메뉴 추가선택 (감자튀김))',
#     'review_text': '호식이 신당점 저번에 먹고 넘 맛있어서 또 주문했어요 ㅜ.... 감자튀김도 맛있고 윙봉세트 가성비 갑! 맵시크랑 간장 맛 굿굿'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 (매운간장),순살 소스선택 (양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '항상 맛있게 잘 먹고 있어요!!'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (간장),뼈 소스선택 (양념),기본음료선택 (스프라이트 500ml 변경),기타 추가선택\t\t (치킨무 빼고 주세요(치킨무X)))',
#     'review_text': '배달도 빠르고 맛도좋고 아주좋아요~!!'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (후라이드),뼈 소스선택 (매운양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '연휴에도 호식이와 함께'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (후라이드),뼈 소스선택 (매운양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '양도많고 담백하니 너무맛있어요 최고'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (매운간장),뼈 소스선택 (양념),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '치킨이 땡겨서 시켰는데 따뜻한데 맛도 있어서 대만족입니다'},
#    {'menus': '허니갈릭치즈볼(6개)/1,뼈한마리/1(뼈 소스선택 (후라이드),음료 추가 선택 (서비스 음료 미제공))',
#     'review_text': '치즈볼이 제가 찾던 맛이라서 좋아요!'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (간장),뼈 소스선택 (양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '맛있게 먹었읍니다,,,'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 ([신메뉴]맵시크(hot)),순살 소스선택 (땡초불꽃),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '요즘 호식이에 푹 빠졌네요 배달도 총알에 양도 넉넉하고 맛은 정말 굿이에요 리뷰 이벤트로 음료수도 업해주셔서 감사하고요 잘 먹었습니다'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1 (순살),치킨소스 선택 (간장),기본음료선택 (코카콜라 제로 500ml 변경),사이드디쉬 변경 (마늘떡볶이))',
#     'review_text': '굿굿굿~~~~~~~'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택 (매운간장),순살 소스선택 (크리스피 골드(국내산 순살)),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '먼가 양이 적어 보이지만 맛있게 먹었습니다.'},
#    {'menus': '맵시크(한마리)+한마리 세트/1(맵시크치킨 분류 선택 (뼈한마리),치킨 분류 선택 (뼈한마리),치킨소스 선택 (간장),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '두마리 시켜서\n나눠두고 먹습니다'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (후라이드),뼈 소스선택 (매운간장),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '맛있고 양도 빨라요 거기다 리뷰이벤트 콜라 사이즈업 까지 너무 감사합니다'},
#    {'menus': '4인 패밀리세트) 두마리+사이드+콜라+치킨무/1(치킨 분류 선택1 ( 뼈한마리),치킨소스 선택 (간장),치킨 분류 선택2 ( 뼈한마리),치킨소스 선택 (후라이드),기본음료선택 (코카콜라 제로 500ml 변경),사이드디쉬 변경 (감자튀김))',
#     'review_text': '맛있습니다😀😍👏👏모두 친절하셨어요~!!\n큰콜라 감사합니다~!'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 ([신메뉴]맵시크(hot)),순살 소스선택 (땡초불꽃),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '신메뉴인데 맛있네요 둘다 순살로 다른 맛을 주문했는데 아주 선택을 잘했네요 리뷰 이벤트로 콜라도 업...  감사해요'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (땡초불꽃),뼈 소스선택 (후라이드),기본음료선택 (스프라이트 500ml 변경))',
#     'review_text': '너무너무 뻣뻣하고 질긴게 어제 치킨 보내준거 같아요ㅠㅠ그렇지 않으면 너무 오래 튀겼나요 암튼 진짜 인생 최악의 치킨입니다 두명이서 먹다가 저만큼이나 남았네요 ㅠㅠ 죄송합니다 너무 뻣뻣하고 맛없는 최악의 치킨이었습니다 하루 실수?이었기를 진심바래봅니다'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1 (순살),치킨소스 선택 (간장),기본음료선택 (콜라 500ml 기본),사이드디쉬 변경 (감자튀김))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 (매운간장),순살 소스선택 (양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '항상 맛있어요\n잘먹었습니다!!'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (매운간장),뼈 소스선택 (매운양념),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '가성비도 좋고 맛있어요'},
#    {'menus': '4인 패밀리세트) 두마리+사이드+콜라+치킨무/1(치킨 분류 선택1 ( 뼈한마리),치킨소스 선택 (후라이드),치킨 분류 선택2 ( 뼈한마리),치킨소스 선택 (매운간장),기본음료선택 (코카콜라 제로 500ml 변경),사이드디쉬 변경 (트리플치즈볼(6개)))',
#     'review_text': '매운간장은 처음 먹어보는데\n매콤하니 너무 맛있어요!'},
# ...
#     'review_text': '매운 간장 맛있네요! 가성비도 최고에요!'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택 (매운간장),순살 소스선택 (후라이드),기본음료선택 (스프라이트 500ml 변경))',
#     'review_text': '너무 바삭하고... 맛있어요.......'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (매운간장),뼈 소스선택 (매운간장),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '늘 여기서 시켜요 \n매운간장\n바삭바삭 너무 맛있어요'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (매운간장),뼈 소스선택 (불짬뽕),기본음료선택 (스프라이트 500ml 변경),기타 추가선택\t\t (치킨무 빼고 주세요(치킨무X)))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 (매운간장),순살 소스선택 ([신메뉴]맵시크(hot)),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': 'good!!!!!!'},
#    {'menus': '뼈한마리/1(뼈 소스선택 (후라이드),음료 추가 선택 (서비스 음료 미제공),기타 추가선택\t\t (치킨무 빼고 주세요(치킨무X)))',
#     'review_text': '오랜만에 생각나서 시켰는데 역시 맛있네요'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (후라이드),뼈 소스선택 (간장),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '맛있게 먹었읍니다,,,'},
#    {'menus': '뼈한마리/1(뼈 소스선택 (간장),음료 추가 선택 (코카콜라 제로 500ml),기타 추가선택\t\t ( 코카콜라 제로 500ml 추가))',
#     'review_text': '음료 사이즈업 감동 감사합니당ㅠㅠ 맛있어요!!'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1 ( 뼈한마리),치킨소스 선택 ([신메뉴]맵시크(hot)),기본음료선택 (코카콜라 제로 500ml 변경),사이드디쉬 변경 (감자튀김))',
#     'review_text': '잘 먹었습니다~^^\n\n\n동의없는 개인정보 제공시 5년이하 5,000만원 이하의 벌금입니다..'},
#    {'menus': '다리＋날개/1(다리＋날개 소스선택 (양념),다리＋날개 소스선택 (후라이드),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '맛잇어요맛닛어요맛잇어요'},
#    {'menus': '다리만/1(다리 소스선택 (양념),다리 소스선택 (간장),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '맛있어요 배달도 적당'},
#    {'menus': '특수부위 단품/2(추가 소스 선택 (양념소스),기본 (닭발／똥집튀김（반반）),기본음료선택 (스프라이트 500ml 변경))',
#     'review_text': '항시 맛있게 잘 먹고 있습니다'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택 (후라이드),플라윙 소스선택 (양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '맛잇어요 좋아요 굿굿'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 (매운간장),순살 소스선택 (매운간장),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': 'good!!!!!!'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택 (매운간장),순살 소스선택 (양념),기본음료선택 (코카콜라 제로 500ml 변경))',
#     'review_text': '어제 먹었는데 오늘 또 먹으려고요 ㅎㅎ...'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택 (후라이드),뼈 소스선택 (매운양념),기본음료선택 (콜라 500ml 기본))',
#     'review_text': '맛있고 기름이 깔끔한맛'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택([신메뉴]맵시크(hot)),플라윙 소스선택(매운간장),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(매운간장),뼈 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '매운양념 너무 맛있어요 고기도 바삭하게 잘 튀겨지고 배달도 빠릅니다'},
#    {'menus': '순살치킨/1(순살 소스선택(양념),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '역시 호식이 양념 너무 맛있어요. 너무 달지도 짜지도 않게 항상 잘 먹고 있습니다'},
#    {'menus': '한마리/1(뼈 소스선택(청양고추마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '정말정말 너무 맛있어요'},
#    {'menus': '크리스피 골드(국내산 순살) 단품/1(딜요거트 소스 추가(딜요거트 소스(40g) 추가),기본음료선택(콜라 500ml 기본))',
#     'review_text': '양많고 정말 맛나네요'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1(뼈한마리),치킨소스 선택(후라이드),기본음료선택(콜라 500ml 기본),사이드디쉬 변경(감자튀김))',
#     'review_text': '역시 후라이드가 맛있네요. \n튀김 옷 바삭하고, 간도 적절하고~ \n감자튀김도 맛있게 잘 먹었습니다.'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(후라이드),순살 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '배달도 빠르고 맛있어요'},
#    {'menus': '순살치킨/1(순살 소스선택(양념),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛있어요 잘먹었습니다'},
#    {'menus': '특수부위 단품/2(추가 소스 선택(양념소스),기본(닭발／똥집튀김（반반）),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '누락된 부분 사장님께서 직접 와주셔서 황송했습니다\n맛있게 잘 먹었습니다'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택([신메뉴]맵시크(hot)),순살 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛있게 잘 먹었슺니다. 다만 박스 입구를 봉해주시는게 맞는듯 합니다.'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(후라이드),순살 소스선택(간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '잘 받았습니다. \n맛있게 잘먹겠습니다.'},
#    {'menus': '한마리/1(뼈 소스선택(매운간장),기본음료선택(콜라 500ml 기본),기타 추가선택(무추가))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(매운간장),뼈 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '믿고 먹습니다 맛있어요'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택(매운간장),플라윙 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '플라윙을 알고서 이거만 시킵니다.\n+역시 호식이는 매운 간장이죠'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(매운간장),순살 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '여러점 시켜봤는데 신당점이 최고입니다\n양념이 확실히 달라요'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(후라이드),순살 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '배달도 빨리오고 \n치킨도 촉촉하게 너무 맛있게 잘 먹었어요\n순살 뼈 둘다 맛있네요~~^^'},
#    {'menus': '크리스피 골드(국내산 순살)+한마리 세트/1(딜요거트 소스 추가(딜요거트 소스(40g) 추가),치킨 분류 선택(순살),치킨소스 선택([신메뉴]맵시크(hot)),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '일주일 동안 3번 먹었습니다. 더 말할 필요 없어요. 너무 맛있어요.'},
#    {'menus': '크리스피 골드(국내산 순살) 단품/1(딜요거트 소스 추가(딜요거트 소스(40g) 추가),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛있습니데. 처음시켜봤는데 상당히좋네요'},
#    {'menus': '맵시크(한마리)+한마리 세트/1(맵시크치킨 분류 선택(순살),치킨 분류 선택(순살),치킨소스 선택(수라깐풍),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '신메뉴 매콤한게 맛있네요. 깐풍맛이랑 단짠단짠 잘 어울려서 맛있게 먹었습니다.'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1(순살),치킨소스 선택(후라이드),기본음료선택(콜라 500ml 기본),사이드디쉬 변경(허니갈릭치즈볼(6개)))',
#     'review_text': '맛있네요^^순살 시켜먹는데 노릇노릇 잘 튀겨주셨어요.'},
#    {'menus': '레몬크림탕슈（안심） 단품/1(기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '레몬크림탕슈는 정말 맛있음!'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(양념),순살 소스선택(간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '뼈 있는 양념 치킨과 간장 순살 시켰는데 두가지 모두 맛있어요~ 맵지 않아 아이도 잘 먹네요~~'},
#    {'menus': '순살치킨/1(순살 소스선택(양념),기본음료선택(콜라 500ml 기본))',
#     'review_text': '꿀맛입니다.\n담에 또 주문하겠습니다'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(매운간장),순살 소스선택(양념),기본음료선택(콜라 500ml 기본))',
#     'review_text': '가까운 곳이 새로 생겨서 자주 시켜먹고 있는데\n너무 맛있어요~'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(매운간장),뼈 소스선택(양념),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '요청사항도 잘 들어주시고 배달도 예상 시간보다 빨라서 좋았어요 곧 이사인데 이사 전까지 호식이는 신당점에서만 먹을 것 같습니다 :) 신당점 짱짱'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(후라이드),뼈 소스선택(스윗츠갈릭),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '배달도빠르고 맛있어요'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(후라이드),순살 소스선택(매운양념),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛도있고 바삭바삭해서 넘좋았어요'},
#    {'menus': '4인 패밀리세트) 두마리+사이드+콜라+치킨무/1(치킨 분류 선택1(순살),치킨소스 선택(양념),치킨 분류 선택2(순살),치킨소스 선택(후라이드),기본음료선택(코카콜라 제로 1.25L 사이즈업),사이드디쉬 변경(감자튀김))',
#     'review_text': '믿고 먹는 호식이입니다'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(매운간장),순살 소스선택(양념),기본음료선택(콜라 500ml 기본))',
#     'review_text': '집 근처에 생겨서 먹었는데\n너무 맛있네요\n또 시켜 먹을게요'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택([신메뉴]맵시크(hot)),플라윙 소스선택(매운간장),기본음료선택(코카콜라 제로 500ml 변경)),무추가/1',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '한마리/1(뼈 소스선택(매운간장),기본음료선택(코카콜라 제로 500ml 변경),치킨스낵 사이드디쉬 추가선택(통살가득 텐더킹(5pc)+양념소스(50g)))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1(뼈한마리),치킨소스 선택(매운간장),기본음료선택(코카콜라 제로 500ml 변경),사이드디쉬 변경(똥집 땡초미니튀김))',
#     'review_text': 'good!!!!!!'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(간장),순살 소스선택([신메뉴]맵시크(hot)),기본음료선택(코카콜라 제로 500ml 변경),사이드 메뉴 추가선택(마늘떡볶이))',
#     'review_text': '꽤 먼 거리인데도 소스도 안 묻고, 콜라도 안 흔들리고, 정말 따끈따끈하게 잘 도착했습니다. 신메뉴라서 한번 시켜봤는데 매콤해서 밥이랑 먹기 너무 좋네요. 자극적인 맛이라 보통의 치킨을 원하신다면 양념이나 매운양념이 좋을 것 같아요. 간장이랑 같이 시켰는데 간장이 많이 묻히는 느낌이었습니다! 양념이랑 간장인데도 눅눅하지 않고 정말 바삭바삭해요. 다음에는 떡볶이 말고 감자튀김과 같이 먹어보겠습니다 ㅎㅎ (소주는 저희 집 냉장고에서 가져왔습니다.)'},
#    {'menus': '수라깐풍（한마리）＋한마리 세트/1(수라깐풍치킨 분류 선택(순살),치킨 분류 선택(순살),치킨소스 선택(청양고추마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '일주일에 한번 치킨 먹을 때마다 시켜먹는데 맛은 항상 좋습니다. 사장님도 친절하시구요. 매번 잘 먹고 있습니다.'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택(후라이드),플라윙 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '깔끔하게 맛있어요 .\n잘 먹었어요.'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(매운간장),뼈 소스선택(양념),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '맛있게 잘먹었습니다.'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(매운간장),뼈 소스선택(불짬뽕),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(간장),뼈 소스선택(매운간장),기본음료선택(콜라 500ml 기본),기타 추가선택(무추가))',
#     'review_text': '매운간장 넘 맛있아요'},
#    {'menus': '레몬크림탕슈（안심）＋한마리 세트/1(치킨분류 선택(순살),치킨소스 선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛있게 잘 먹었습니다. 감사합니다:)'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(간장),순살 소스선택(후라이드),기본음료선택(콜라 500ml 기본))',
#     'review_text': '순살후라이드는 짜지도않고 부드러운 물반죽이라 아이 먹이기도 좋네요'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(New）타코마요),뼈 소스선택(후라이드),기본음료선택(콜라 500ml 기본))',
#     'review_text': '☆☆☆☆☆☆☆☆☆☆'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(간장),순살 소스선택(크리스피 골드(국내산 순살)),기본음료선택(콜라 500ml 기본))',
#     'review_text': '맛있게 잘 먹었습니다~'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(후라이드),뼈 소스선택(New）타코마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '배달도빠르고 맛있어요'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택(후라이드),플라윙 소스선택(매운간장),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '맛있어요. 맛있어요.'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(크리스피 골드(국내산 순살)),순살 소스선택(청양고추마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '맛있게 먹어요 감사합니다'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(매운간장),순살 소스선택(후라이드),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '배달 빠르고 맛있어요 좋아요'},
#    {'menus': '수라깐풍（한마리）＋한마리 세트/1(수라깐풍치킨 분류 선택(순살),치킨 분류 선택(순살),치킨소스 선택(청양고추마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '주에 1번은 먹는 것 같은데 수라깐풍이 가장 맛있습니다. 청양마요도 두번째로 맛있다 할만 합니다. 수라깐풍 청양 마요 조합 좋습니다.'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(매운간장),순살 소스선택(매운간장),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': 'good!!!!!!'},
#    {'menus': '수라깐풍（한마리）＋한마리 세트/1(수라깐풍치킨 분류 선택(순살),치킨 분류 선택(순살),치킨소스 선택(청양고추마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '수라깐풍 신제품이라고 3번 주문 중에 3번 시켜먹는데 정말 맛있습니다. 다른 한마리는 돌아가면서 먹는데 마요맛도 맛있게 먹었습니다. 마라깐풍은 먹어본 양념치킨 중에 가장 맛있습니다. 사장님도 친절하시고 치킨 상태도 좋습니다.'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(후라이드),뼈 소스선택(New）타코마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '타코마요 처음 먹어보는데 맛있습니당\n시그니처 메뉴가 되면 좋겠네요'},
#    {'menus': '2인 커플세트) 한마리+사이드+콜라+치킨무/1(치킨 분류 선택1(순살),치킨소스 선택(간장),기본음료선택(콜라 500ml 기본),사이드디쉬 변경(마늘떡볶이))',
#     'review_text': '가성비좋은 메뉴입니다.'},
#    {'menus': '순살치킨 ＋ 순살치킨/1(순살 소스선택(매운간장),순살 소스선택(양념),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '너무 맛있습니다!!\n또 시켜먹을게요!!'},
#    {'menus': '참이슬 후레쉬 (병) - 360ml/2,순살치킨 ＋ 순살치킨/1(순살 소스선택(크리스피 골드(국내산 순살)),순살 소스선택(양념),기본음료선택(코카콜라 제로 1.25L 사이즈업))',
#     'review_text': '요기요 고객센터...'},
#    {'menus': '한마리 ＋ 순살치킨/1(뼈 소스선택(후라이드),순살 소스선택(양념),기본음료선택(콜라 500ml 기본),기타 추가선택(무추가))',
#     'review_text': '항상 만족합니다 장사잘되시길 ㅎㅎ'},
#    {'menus': '특수부위 세트/1(세트 선택(똥집튀김＋치킨세트),추가 소스 선택(땡초소스),치킨분류 선택(뼈한마리),치킨소스 선택(후라이드),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '맛있게 잘먹엇습니다'},
#    {'menus': '수라깐풍（한마리）＋한마리 세트/1(수라깐풍치킨 분류 선택(순살),치킨 분류 선택(순살),치킨소스 선택(매운양념),기본음료선택(콜라 500ml 기본))',
#     'review_text': '호식이 처음 먹어봤는데 깐풍맛 정말 맛있습니다.'},
#    {'menus': '수라깐풍（한마리）＋한마리 세트/1(수라깐풍치킨 분류 선택(순살),치킨 분류 선택(순살),치킨소스 선택(New）타코마요),기본음료선택(코카콜라 제로 500ml 변경))',
#     'review_text': '호식이 근처에 생겨서 두번째로 먹는건데 깐풍맛이 정말 맛있었어요. 적극 추천할만한 맛입니다.'},
#    {'menus': '[살사세트] 순살 2세트(소스선택)+사이드 1개+코카콜라 500ml/1(순살 소스선택(땡초불꽃),순살 소스선택(매운양념),기본음료선택(콜라 500ml 기본),사이드디쉬 변경(마늘떡볶이))',
#     'review_text': '호식이가 좀 가까워져서 가끔 부담없이 주문을 하겠네요 양도 맛도 좋네요 거기에 콜라도 업해주셔서 너무 감사합니다 맛있게 잘 먹었습니다'},
#    {'menus': '특수부위 단품/2(추가 소스 선택(양념소스),기본(닭발／똥집튀김（반반）),기본음료선택(스프라이트 500ml 변경))',
#     'review_text': '호식이치킨이 사라져서 너무나 아쉬웠는데, 다시금 신당점이 부활해서 너무너무 기쁩니다.\n주문하지 못한 땡초소스까지 서비스로 주셔서 너무나 감사합니다'},
#    {'menus': '한마리 ＋ 한마리/1(뼈 소스선택(매운간장),뼈 소스선택(매운간장),기본음료선택(콜라 500ml 기본))',
#     'review_text': '너무 맛있어요 바삭하고 양념도 맛있네요\n 이동네에 호식이 다시 생겨서 너무 좋아요'},
#    {'menus': '[살사세트] 순살 2세트(소스선택)+사이드 1개+코카콜라 500ml/1(순살 소스선택(후라이드),순살 소스선택(간장),기본음료선택(코카콜라 제로 500ml 변경),사이드디쉬 변경(감자튀김))',
#     'review_text': '너무 맛있네용!!\n양이 너무많아서좋은~~\n조금 남았네요ㅜㅜ'},
#    {'menus': '[투원세트] 치킨 2마리(소스선택)+사이드 1개+코카콜라 500ml/1(뼈 소스선택(매운간장),뼈 소스선택(후라이드),기본음료선택(코카콜라 제로 500ml 변경),사이드디쉬 변경(똥집 미니튀김(조미소금)))',
#     'review_text': '매운간장 존맛이네요 올만에먹은건데\n이지점  매운간장은 최곱니다'},
#    {'menus': '[투원세트] 치킨 2마리(소스선택)+사이드 1개+코카콜라 500ml/1(뼈 소스선택(매운간장),뼈 소스선택(양념),기본음료선택(콜라 500ml 기본),사이드디쉬 변경(감자튀김))',
#     'review_text': '호식이 신당점에사 자주사먹었던 사람입니다.\n작년에 갑자기 없어져서 너무 슬펐는데 어제 갑자기 오픈한걸보고 너무 신나서 오늘 시켜 먹었습니다. \n주인장이 바뀐건지 아니면 잠깐 쉬시고 다시 장사하시는건지 모르겠지만 너무 반가워요!\n\n맛은 이전보다 치킨이 좀더 바삭해지고 매운간장은 더 매워졌고 양념은 좀더 끈적해졌습니다.\n\n계속 열심히 시켜먹어보겠습니다!!'},
#    {'menus': '플라윙세트（윙＋봉＋콜라）/1(플라윙 소스선택(매운간장),플라윙 소스선택(땡초불꽃),기본음료선택(코카콜라 제로 500ml 변경),기타 추가선택(무추가))',
#     'review_text': '집이랑 가까워서 바삭한 상태로 먹을 수 있었어요~\n추천합니다\n근데 윙/봉 따로 분리해서 요청했는데\n그렇게 담아주셨으면 더 좋았을 거 같아요\n맛은 말해뭐해 최고입니당'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1436357/'},
#  {'_id': '1423309',
#   'restaurant': '육회바른연어-옥수점',
#   'reviews': [{'menus': '혼밥세트2/1(혼밥세트2 ((변경)육회100+육초3+육덮곱빼기),덮밥추가 ([추가]덮밥육회30g))',
#     'review_text': '주문 오배송이 잦았으나 맛은 있습니다.'},
#    {'menus': '육회덮밥/1(육회덮밥 ((선택)육회덮밥 보통))', 'review_text': '항상 맛있게 먹고 있어요'},
#    {'menus': '모듬초밥/1(모듬초밥 ((선택)육회초밥4p+연어초밥4p+스테이크초밥4p))',
#     'review_text': '초밥에 검은색 이물질, 락교에도 이물질이 있었어요 그래서 별하나 뺍니다'},
#    {'menus': '혼밥세트2/1(혼밥세트2 ((선택)육회100+육초3+육덮))',
#     'review_text': '너무너무 맛있어요\n일주일에 두번은 먹는것 같아요'},
#    {'menus': '혼밥세트1/1(혼밥세트1 ((변경)육덮곱빼기+육회초밥3p),덮밥추가 ([추가]덮밥육회30g))',
#     'review_text': '곱배기를 주문했는데 종이 그릇만 곱배기이고 양은 일반이었네요\n그 이후에 주문한 곱배기도 일반 양이었습니다.'},
#    {'menus': '육회쫄면/1(육회쫄면 ((선택)육회쫄면1인분)),최상급 육회/1(최상급 육회 ((선택)육회한접시180))',
#     'review_text': '맛있게 잘 먹었습니다..'},
#    {'menus': '혼술세트2/1(혼술세트2 ((변경)육회100+연어8p+연어초밥3p),육회연어추가 ([추가]육회100g))',
#     'review_text': '10% 추가할인이 중량 10%때먹고 추가할인인줄 몰랐습니다.\n다음번엔 선고지 부탁드려요.'},
#    {'menus': '육회쫄면/1(육회쫄면 ((선택)육회쫄면1인분)),불육회덮밥/1(불육회덮밥 ((선택)불육회덮밥 보통))',
#     'review_text': '무지 맵고 .. 맛을 평가 할 수도 없네요'},
#    {'menus': '최상급 육회/1(최상급 육회 ((변경)육회큰놈270)),[추가]육회소스/1,[추가]김/1',
#     'review_text': '진짜 항상 잘먹고 있습니다! 곧 이사가서 육바연 옥수점 육회를 못먹게 되는데 넘 아쉬울 정도.. 늘 생각날것같아요 😭🫶'},
#    {'menus': '최상급 육회/1(최상급 육회 ((변경)육회큰놈270)),[추가]육회소스/1,[추가]김/1',
#     'review_text': '육회 양도 많구 맛있어요!! 진짜 혼술 안주로 이만한게 없는 것 같아요!! 김에 싸먹는 거 진짜 추천 🤤'},
#    {'menus': '육회덮밥/1(육회덮밥 ((선택)육회덮밥 보통))', 'review_text': '항상 맛있게 먹고있습니다'},
#    {'menus': '육회덮밥/1(육회덮밥((선택)육회덮밥 보통))', 'review_text': '항상 맛있게 먹고 있습니다'},
#    {'menus': '혼밥세트2 (육회100g＋육초3＋육덮)/1,핵꿀맛 육회초밥 6p/1',
#     'review_text': '진짜 후회없는 맛집!!! 달달고소해서 너무 좋구 가성비도 좋아ㅕㅕ'},
#    {'menus': '육회덮밥/2', 'review_text': '육회덮밥 기복없이 맛있습니다'},
#    {'menus': '육회덮밥/2', 'review_text': '7900... 이전보단 자주 못시켜먹겠지만 굿이네요'},
#    {'menus': '육바연 3단변신초밥 5p/1(3단변신초밥(추가 5p (총 10p))),스테이크초밥 12p/1,김/1',
#     'review_text': '맛있게잘먹었어요^^'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1,육회덮밥/1', 'review_text': '맛있게 잘 먹었습미다'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1(육회, 연어 추가((추가)육회180g 추가))',
#     'review_text': '도착한 지 15분도 되지 않아 지구상에서 사라져 버리고 말았습니다 뿅!!!! 꺄하하하하하'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/2', 'review_text': '맛있게 잘먹었어요 ㅎㅎ 추천합니당!!'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1,육회덮밥/1', 'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1,육회덮밥/1(사이드 추가(날치알주먹밥))',
#     'review_text': '맛있고 배달도 빨라서 좋아요'},
#    {'menus': '육회덮밥/1(소스 추가선택(날치알 추가))',
#     'review_text': '가성비 좋아요. 한동안 어플 가격은 낮았었는데 이제 매장 가격과 같아졌네요.'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/2', 'review_text': '넘넘 맛있게 잘 먹었어요!!'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1(사이드 추가(날치알주먹밥))',
#     'review_text': '리뷰보니 작은연어도 있고 큰연어도 있어서 걱정했는데 작은연어로 넉넉하게왔어요👍'},
#    {'menus': '최상급육회 큰놈 (270g)/1',
#     'review_text': '육바연 단골이에요.\n근데 여긴 육회를 좀 더 죠수다...? 다진다..? 그런것 같아요.\n뭐 빼달란게 많아 사진은 비닐보따리로 합니다...\n맛있었어요. 감사합니다.'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1', 'review_text': '맛잇게\n잘먹엇습니다!!'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1', 'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '생생한 생연어초밥 6p/1,육회덮밥/1,생연어덮밥/1',
#     'review_text': '이번테도 맛있게 잘 먹었어요 ^*^'},
#    {'menus': '혼밥세트2 (육회100g＋육초3＋육덮)/1', 'review_text': '늘 잘먹고있어요!!! 육바연 최공'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1(육회, 연어 추가((추가)육회100g 추가))',
#     'review_text': '연어는 한점 크기가 생각보다 작긴했지만 \n육회는 너무 맛있었습니당'},
#    {'menus': '육회덮밥/1,모듬초밥 12p/1', 'review_text': '아들이 늘맛있게  잘 먹네요.강추'},
#    {'menus': '최상급육회 (180g)/1(육회, 연어 추가((추가)매운불육회100g 추가))',
#     'review_text': '제가 지금 매주금요일  마다 야근할때 시켜먹습니다\n다른 지점에비해 할인도 많이하고  배달비도무료\n주문안할이유가없죠'},
#    {'menus': '육바연KING유부세트 (선택유부2＋육초4＋연초4)/1(유부초밥 선택((선택)육회유부초밥))',
#     'review_text': '너무 맛있게 먹었어요 !!!! 육회가 특히 너무 맛남 ,, ♡'},
#    {'menus': '혼밥세트2 (육회100g＋육초3＋육덮)/1',
#     'review_text': '이번엔 먹다가 급하게 찍어서 적어보이지만, 양 많고 맛있어요!! 넘 맛있어서 자주 시켜먹게 되네요 안주 최고!!'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/2,육회덮밥/2', 'review_text': '너무 맛있어요오오옹'},
#    {'menus': '스테이크초밥 6p/1,생생한 생연어초밥 6p/1', 'review_text': '！！！！！！！맛있어요！！！！！！'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1,육회덮밥/1',
#     'review_text': '연어도 날치알이랑 양파랑 타르타르소스 찍어 먹으면 넘 맛있고 육회도 양 많고 흑임자 소스랑 너무 잘 어울려요! 진짜 혼술 안주로 너무 좋은 구성인 것 같습니다🥰'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1', 'review_text': '오 혼술하기 딱 좋네요!'},
#    {'menus': '혼술세트 1 (육회100g＋연어8）/1(육회, 연어 추가((추가)육회100g 추가))',
#     'review_text': '무엇보다 신선하고 맛은좋고 \n양도 푸짐하네요 만족합니다'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1423309/'}]

# %%
KEYWORDS_BLACKLIST = ['리뷰', 'zㅣ쀼', 'ZI쀼', 'Zl쀼', '리쀼', '찜', '이벤트', '추가', '소스']
KEYWORDS_CONTEXT = [
    '해장', '숙취',
    '다이어트'
]

# %%
def is_valid_menu(menu_name):
    return True if not any(keyword in menu_name for keyword in KEYWORDS_BLACKLIST) else False

is_valid_menu('[리쀼] 수박 추가')
# Out:
# False

# %%
def extract_keywords(review_text):
    keywords = []

    for word in review_text.split():
        if any(keyword in word for keyword in KEYWORDS_CONTEXT):
            keywords.append(word)
    return keywords

extract_keywords('완전 맛있었어요. 역시 해장에는 수박주스가 답이네요.')
# Out:
# ['해장에는']

# %%
KEYWORDS_BLACKLIST = ['리뷰', 'zㅣ쀼', 'ZI쀼', 'Zl쀼', '찜', '이벤트', '추가']
KEYWORDS_CONTEXT = [
    '해장', '숙취',
    '다이어트'
]

menu_name2id = {}
menu_db = {}

unique_menus = set()
for index, restaurant in enumerate(restaurants_info):
    menu_name2id = {}
    for reviews in restaurant['reviews']:
        menus = reviews["menus"].split(',')
        review_text = reviews["review_text"]

        # 리뷰에 컨텍스트 관련 키워드 있는 지 확인
        keywords = extract_keywords(review_text)

        # 리뷰에 컨텍스트 관련 키워드 없으면 해당 리뷰 스킵
        if keywords == []:
            continue

        for menu in menus:
            menu_name = menu.split('/')[0]
            # 리뷰 이벤트 관련 메뉴 필터링
            if is_valid_menu(menu_name):
                if not menu_name in menu_name2id:
                    menu_idx = len(menu_name2id)
                    menu_id = '_'.join([restaurant['_id'], str(menu_idx)])
                    menu_name2id[menu_name] = menu_id

                    # Menu DB instances format
                    menu_db[menu_id] = {
                        "restaurant": restaurant["restaurant"],
                        "menu": menu_name,
                        "url": restaurant["url"],
                        "keywords": menu_name.split(),
                        "embeddings": None
                    }
                else:
                    menu_id = menu_name2id[menu_name]

                menu_db[menu_id]["keywords"].extend(keywords)

# %%
len(menu_db)
# Out:
# 2

# %%
menu_db['1363980_0']
# Out:
# {'restaurant': 'BHC-금호동점',
#  'menu': '뿌링클 스틱',
#  'url': 'https://www.yogiyo.co.kr/mobile/#/1363980/',
#  'keywords': ['뿌링클', '스틱', '다이어트중인데'],
#  'embeddings': None}

# %%
import sys
sys.path.insert(0, "..")

from utils import get_embedding

for menu_id in menu_db:
    keywords = menu_db[menu_id]["keywords"] + [menu_db[menu_id]["menu"]]
    embedding = get_embedding(" ".join(keywords), model='text-embedding-3-large')
    menu_db[menu_id]["embeddings"] = embedding

# %%
db = client.menu_db
collection = db.menu_info

# %%
for menu_id in menu_db:
    result = collection.update_one({"_id": menu_id}, {"$set": menu_db[menu_id]}, upsert=True)
